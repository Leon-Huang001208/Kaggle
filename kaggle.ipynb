# %% [markdown]
# # Instruction
#
# Environment: google colab \
# Upload the following files on google drive: \
# train.csv \
# test.csv \
# noisy-images.zip (zip noisy-images folder)

# %%
from __future__ import print_function
import torch
import torchtext
import torchvision.transforms as transforms
from torch import nn, optim
from torchvision import datasets
from torchvision.transforms import ToTensor
from torch.utils.data import Dataset, DataLoader
from torchtext.data.utils import get_tokenizer
from torchtext.vocab import build_vocab_from_iterator
from sklearn.model_selection import train_test_split
from PIL import Image
import torchvision.models as models
import pandas as pd
import numpy as np
import time

# %% [markdown]
# # Import image folder

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !unzip /content/drive/MyDrive/noisy-images.zip
# Out:
# 流式输出内容被截断，只能显示最后 5000 行内容。
#   inflating: noisy-images/3212.jpg
#   inflating: __MACOSX/noisy-images/._3212.jpg
#   inflating: noisy-images/11755.jpg
#   inflating: __MACOSX/noisy-images/._11755.jpg
#   inflating: noisy-images/52888.jpg
#   inflating: __MACOSX/noisy-images/._52888.jpg
#   inflating: noisy-images/12274.jpg
#   inflating: __MACOSX/noisy-images/._12274.jpg
#   inflating: noisy-images/44032.jpg
#   inflating: __MACOSX/noisy-images/._44032.jpg
#   inflating: noisy-images/14605.jpg
#   inflating: __MACOSX/noisy-images/._14605.jpg
#   inflating: noisy-images/9071.jpg
#   inflating: __MACOSX/noisy-images/._9071.jpg
#   inflating: noisy-images/52650.jpg
#   inflating: __MACOSX/noisy-images/._52650.jpg
#   inflating: noisy-images/6342.jpg
#   inflating: __MACOSX/noisy-images/._6342.jpg
#   inflating: noisy-images/35813.jpg
#   inflating: __MACOSX/noisy-images/._35813.jpg
#   inflating: noisy-images/10463.jpg
#   inflating: __MACOSX/noisy-images/._10463.jpg
#   inflating: noisy-images/56436.jpg
#   inflating: __MACOSX/noisy-images/._56436.jpg
#   inflating: noisy-images/59705.jpg
#   inflating: __MACOSX/noisy-images/._59705.jpg
#   inflating: noisy-images/2124.jpg
#   inflating: __MACOSX/noisy-images/._2124.jpg
#   inflating: noisy-images/46625.jpg
#   inflating: __MACOSX/noisy-images/._46625.jpg
#   inflating: noisy-images/51359.jpg
#   inflating: __MACOSX/noisy-images/._51359.jpg
#   inflating: noisy-images/49516.jpg
#   inflating: __MACOSX/noisy-images/._49516.jpg
#   inflating: noisy-images/4555.jpg
#   inflating: __MACOSX/noisy-images/._4555.jpg
#   inflating: noisy-images/19321.jpg
#   inflating: __MACOSX/noisy-images/._19321.jpg
#   inflating: noisy-images/16012.jpg
#   inflating: __MACOSX/noisy-images/._16012.jpg
#   inflating: noisy-images/48608.jpg
#   inflating: __MACOSX/noisy-images/._48608.jpg
#   inflating: noisy-images/50047.jpg
#   inflating: __MACOSX/noisy-images/._50047.jpg
#   inflating: noisy-images/5893.jpg
#   inflating: __MACOSX/noisy-images/._5893.jpg
#   inflating: noisy-images/40254.jpg
#   inflating: __MACOSX/noisy-images/._40254.jpg
#   inflating: noisy-images/37962.jpg
#   inflating: __MACOSX/noisy-images/._37962.jpg
#   inflating: noisy-images/18981.jpg
#   inflating: __MACOSX/noisy-images/._18981.jpg
#   inflating: noisy-images/40532.jpg
#   inflating: __MACOSX/noisy-images/._40532.jpg
#   inflating: noisy-images/29584.jpg
#   inflating: __MACOSX/noisy-images/._29584.jpg
#   inflating: noisy-images/4233.jpg
#   inflating: __MACOSX/noisy-images/._4233.jpg
#   inflating: noisy-images/16774.jpg
#   inflating: __MACOSX/noisy-images/._16774.jpg
#   inflating: noisy-images/39797.jpg
#   inflating: __MACOSX/noisy-images/._39797.jpg
#   inflating: noisy-images/50721.jpg
#   inflating: __MACOSX/noisy-images/._50721.jpg
#   inflating: noisy-images/18759.jpg
#   inflating: __MACOSX/noisy-images/._18759.jpg
#   inflating: noisy-images/49270.jpg
#   inflating: __MACOSX/noisy-images/._49270.jpg
#   inflating: noisy-images/38489.jpg
#   inflating: __MACOSX/noisy-images/._38489.jpg
#   inflating: noisy-images/10305.jpg
#   inflating: __MACOSX/noisy-images/._10305.jpg
#   inflating: noisy-images/59063.jpg
#   inflating: __MACOSX/noisy-images/._59063.jpg
#   inflating: noisy-images/2642.jpg
#   inflating: __MACOSX/noisy-images/._2642.jpg
#   inflating: noisy-images/14163.jpg
#   inflating: __MACOSX/noisy-images/._14163.jpg
#   inflating: noisy-images/9717.jpg
#   inflating: __MACOSX/noisy-images/._9717.jpg
#   inflating: noisy-images/52136.jpg
#   inflating: __MACOSX/noisy-images/._52136.jpg
#   inflating: noisy-images/6424.jpg
#   inflating: __MACOSX/noisy-images/._6424.jpg
#   inflating: noisy-images/53228.jpg
#   inflating: __MACOSX/noisy-images/._53228.jpg
#   inflating: noisy-images/8409.jpg
#   inflating: __MACOSX/noisy-images/._8409.jpg
#   inflating: noisy-images/44754.jpg
#   inflating: __MACOSX/noisy-images/._44754.jpg
#   inflating: noisy-images/55881.jpg
#   inflating: __MACOSX/noisy-images/._55881.jpg
#   inflating: noisy-images/23917.jpg
#   inflating: __MACOSX/noisy-images/._23917.jpg
#   inflating: noisy-images/12512.jpg
#   inflating: __MACOSX/noisy-images/._12512.jpg
#   inflating: noisy-images/54547.jpg
#   inflating: __MACOSX/noisy-images/._54547.jpg
#   inflating: noisy-images/42331.jpg
#   inflating: __MACOSX/noisy-images/._42331.jpg
#   inflating: noisy-images/13618.jpg
#   inflating: __MACOSX/noisy-images/._13618.jpg
#   inflating: noisy-images/52122.jpg
#   inflating: __MACOSX/noisy-images/._52122.jpg
#   inflating: noisy-images/9703.jpg
#   inflating: __MACOSX/noisy-images/._9703.jpg
#   inflating: noisy-images/6430.jpg
#   inflating: __MACOSX/noisy-images/._6430.jpg
#   inflating: noisy-images/15269.jpg
#   inflating: __MACOSX/noisy-images/._15269.jpg
#   inflating: noisy-images/55895.jpg
#   inflating: __MACOSX/noisy-images/._55895.jpg
#   inflating: noisy-images/44740.jpg
#   inflating: __MACOSX/noisy-images/._44740.jpg
#   inflating: noisy-images/54553.jpg
#   inflating: __MACOSX/noisy-images/._54553.jpg
#   inflating: noisy-images/12506.jpg
#   inflating: __MACOSX/noisy-images/._12506.jpg
#   inflating: noisy-images/18995.jpg
#   inflating: __MACOSX/noisy-images/._18995.jpg
#   inflating: noisy-images/40526.jpg
#   inflating: __MACOSX/noisy-images/._40526.jpg
#   inflating: noisy-images/19453.jpg
#   inflating: __MACOSX/noisy-images/._19453.jpg
#   inflating: noisy-images/4227.jpg
#   inflating: __MACOSX/noisy-images/._4227.jpg
#   inflating: noisy-images/47249.jpg
#   inflating: __MACOSX/noisy-images/._47249.jpg
#   inflating: noisy-images/50735.jpg
#   inflating: __MACOSX/noisy-images/._50735.jpg
#   inflating: noisy-images/39783.jpg
#   inflating: __MACOSX/noisy-images/._39783.jpg
#   inflating: noisy-images/16760.jpg
#   inflating: __MACOSX/noisy-images/._16760.jpg
#   inflating: noisy-images/28856.jpg
#   inflating: __MACOSX/noisy-images/._28856.jpg
#   inflating: noisy-images/5139.jpg
#   inflating: __MACOSX/noisy-images/._5139.jpg
#   inflating: noisy-images/56344.jpg
#   inflating: __MACOSX/noisy-images/._56344.jpg
#   inflating: noisy-images/2656.jpg
#   inflating: __MACOSX/noisy-images/._2656.jpg
#   inflating: noisy-images/59077.jpg
#   inflating: __MACOSX/noisy-images/._59077.jpg
#   inflating: noisy-images/56422.jpg
#   inflating: __MACOSX/noisy-images/._56422.jpg
#   inflating: noisy-images/10477.jpg
#   inflating: __MACOSX/noisy-images/._10477.jpg
#   inflating: noisy-images/2130.jpg
#   inflating: __MACOSX/noisy-images/._2130.jpg
#   inflating: noisy-images/59711.jpg
#   inflating: __MACOSX/noisy-images/._59711.jpg
#   inflating: noisy-images/46631.jpg
#   inflating: __MACOSX/noisy-images/._46631.jpg
#   inflating: noisy-images/17318.jpg
#   inflating: __MACOSX/noisy-images/._17318.jpg
#   inflating: noisy-images/49502.jpg
#   inflating: __MACOSX/noisy-images/._49502.jpg
#   inflating: noisy-images/19335.jpg
#   inflating: __MACOSX/noisy-images/._19335.jpg
#   inflating: noisy-images/4541.jpg
#   inflating: __MACOSX/noisy-images/._4541.jpg
#   inflating: noisy-images/16006.jpg
#   inflating: __MACOSX/noisy-images/._16006.jpg
#   inflating: noisy-images/11769.jpg
#   inflating: __MACOSX/noisy-images/._11769.jpg
#   inflating: noisy-images/5887.jpg
#   inflating: __MACOSX/noisy-images/._5887.jpg
#   inflating: noisy-images/43749.jpg
#   inflating: __MACOSX/noisy-images/._43749.jpg
#   inflating: noisy-images/12260.jpg
#   inflating: __MACOSX/noisy-images/._12260.jpg
#   inflating: noisy-images/44026.jpg
#   inflating: __MACOSX/noisy-images/._44026.jpg
#   inflating: noisy-images/7048.jpg
#   inflating: __MACOSX/noisy-images/._7048.jpg
#   inflating: noisy-images/43991.jpg
#   inflating: __MACOSX/noisy-images/._43991.jpg
#   inflating: noisy-images/9065.jpg
#   inflating: __MACOSX/noisy-images/._9065.jpg
#   inflating: noisy-images/14611.jpg
#   inflating: __MACOSX/noisy-images/._14611.jpg
#   inflating: noisy-images/45338.jpg
#   inflating: __MACOSX/noisy-images/._45338.jpg
#   inflating: noisy-images/6356.jpg
#   inflating: __MACOSX/noisy-images/._6356.jpg
#   inflating: noisy-images/35807.jpg
#   inflating: __MACOSX/noisy-images/._35807.jpg
#   inflating: noisy-images/23056.jpg
#   inflating: __MACOSX/noisy-images/._23056.jpg
#   inflating: noisy-images/13195.jpg
#   inflating: __MACOSX/noisy-images/._13195.jpg
#   inflating: noisy-images/24739.jpg
#   inflating: __MACOSX/noisy-images/._24739.jpg
#   inflating: noisy-images/33245.jpg
#   inflating: __MACOSX/noisy-images/._33245.jpg
#   inflating: noisy-images/25427.jpg
#   inflating: __MACOSX/noisy-images/._25427.jpg
#   inflating: noisy-images/52877.jpg
#   inflating: __MACOSX/noisy-images/._52877.jpg
#   inflating: noisy-images/14822.jpg
#   inflating: __MACOSX/noisy-images/._14822.jpg
#   inflating: noisy-images/8390.jpg
#   inflating: __MACOSX/noisy-images/._8390.jpg
#   inflating: noisy-images/22348.jpg
#   inflating: __MACOSX/noisy-images/._22348.jpg
#   inflating: noisy-images/21641.jpg
#   inflating: __MACOSX/noisy-images/._21641.jpg
#   inflating: noisy-images/59922.jpg
#   inflating: __MACOSX/noisy-images/._59922.jpg
#   inflating: noisy-images/31452.jpg
#   inflating: __MACOSX/noisy-images/._31452.jpg
#   inflating: noisy-images/46802.jpg
#   inflating: __MACOSX/noisy-images/._46802.jpg
#   inflating: noisy-images/21899.jpg
#   inflating: __MACOSX/noisy-images/._21899.jpg
#   inflating: noisy-images/28103.jpg
#   inflating: __MACOSX/noisy-images/._28103.jpg
#   inflating: noisy-images/27230.jpg
#   inflating: __MACOSX/noisy-images/._27230.jpg
#   inflating: noisy-images/38310.jpg
#   inflating: __MACOSX/noisy-images/._38310.jpg
#   inflating: noisy-images/17495.jpg
#   inflating: __MACOSX/noisy-images/._17495.jpg
#   inflating: noisy-images/38476.jpg
#   inflating: __MACOSX/noisy-images/._38476.jpg
#   inflating: noisy-images/20239.jpg
#   inflating: __MACOSX/noisy-images/._20239.jpg
#   inflating: noisy-images/37745.jpg
#   inflating: __MACOSX/noisy-images/._37745.jpg
#   inflating: noisy-images/26890.jpg
#   inflating: __MACOSX/noisy-images/._26890.jpg
#   inflating: noisy-images/50906.jpg
#   inflating: __MACOSX/noisy-images/._50906.jpg
#   inflating: noisy-images/16953.jpg
#   inflating: __MACOSX/noisy-images/._16953.jpg
#   inflating: noisy-images/31334.jpg
#   inflating: __MACOSX/noisy-images/._31334.jpg
#   inflating: noisy-images/26648.jpg
#   inflating: __MACOSX/noisy-images/._26648.jpg
#   inflating: noisy-images/2865.jpg
#   inflating: __MACOSX/noisy-images/._2865.jpg
#   inflating: noisy-images/21127.jpg
#   inflating: __MACOSX/noisy-images/._21127.jpg
#   inflating: noisy-images/48191.jpg
#   inflating: __MACOSX/noisy-images/._48191.jpg
#   inflating: noisy-images/35152.jpg
#   inflating: __MACOSX/noisy-images/._35152.jpg
#   inflating: noisy-images/33523.jpg
#   inflating: __MACOSX/noisy-images/._33523.jpg
#   inflating: noisy-images/23730.jpg
#   inflating: __MACOSX/noisy-images/._23730.jpg
#   inflating: noisy-images/35146.jpg
#   inflating: __MACOSX/noisy-images/._35146.jpg
#   inflating: noisy-images/15296.jpg
#   inflating: __MACOSX/noisy-images/._15296.jpg
#   inflating: noisy-images/25355.jpg
#   inflating: __MACOSX/noisy-images/._25355.jpg
#   inflating: noisy-images/9924.jpg
#   inflating: __MACOSX/noisy-images/._9924.jpg
#   inflating: noisy-images/32629.jpg
#   inflating: __MACOSX/noisy-images/._32629.jpg
#   inflating: noisy-images/44967.jpg
#   inflating: __MACOSX/noisy-images/._44967.jpg
#   inflating: noisy-images/7909.jpg
#   inflating: __MACOSX/noisy-images/._7909.jpg
#   inflating: noisy-images/33537.jpg
#   inflating: __MACOSX/noisy-images/._33537.jpg
#   inflating: noisy-images/34258.jpg
#   inflating: __MACOSX/noisy-images/._34258.jpg
#   inflating: noisy-images/23724.jpg
#   inflating: __MACOSX/noisy-images/._23724.jpg
#   inflating: noisy-images/38462.jpg
#   inflating: __MACOSX/noisy-images/._38462.jpg
#   inflating: noisy-images/17481.jpg
#   inflating: __MACOSX/noisy-images/._17481.jpg
#   inflating: noisy-images/37751.jpg
#   inflating: __MACOSX/noisy-images/._37751.jpg
#   inflating: noisy-images/59088.jpg
#   inflating: __MACOSX/noisy-images/._59088.jpg
#   inflating: noisy-images/28671.jpg
#   inflating: __MACOSX/noisy-images/._28671.jpg
#   inflating: noisy-images/16947.jpg
#   inflating: __MACOSX/noisy-images/._16947.jpg
#   inflating: noisy-images/27542.jpg
#   inflating: __MACOSX/noisy-images/._27542.jpg
#   inflating: noisy-images/31320.jpg
#   inflating: __MACOSX/noisy-images/._31320.jpg
#   inflating: noisy-images/48185.jpg
#   inflating: __MACOSX/noisy-images/._48185.jpg
#   inflating: noisy-images/21133.jpg
#   inflating: __MACOSX/noisy-images/._21133.jpg
#   inflating: noisy-images/59936.jpg
#   inflating: __MACOSX/noisy-images/._59936.jpg
#   inflating: noisy-images/30980.jpg
#   inflating: __MACOSX/noisy-images/._30980.jpg
#   inflating: noisy-images/36329.jpg
#   inflating: __MACOSX/noisy-images/._36329.jpg
#   inflating: noisy-images/31446.jpg
#   inflating: __MACOSX/noisy-images/._31446.jpg
#   inflating: noisy-images/29209.jpg
#   inflating: __MACOSX/noisy-images/._29209.jpg
#   inflating: noisy-images/46816.jpg
#   inflating: __MACOSX/noisy-images/._46816.jpg
#   inflating: noisy-images/5878.jpg
#   inflating: __MACOSX/noisy-images/._5878.jpg
#   inflating: noisy-images/11796.jpg
#   inflating: __MACOSX/noisy-images/._11796.jpg
#   inflating: noisy-images/28117.jpg
#   inflating: __MACOSX/noisy-images/._28117.jpg
#   inflating: noisy-images/30758.jpg
#   inflating: __MACOSX/noisy-images/._30758.jpg
#   inflating: noisy-images/10488.jpg
#   inflating: __MACOSX/noisy-images/._10488.jpg
#   inflating: noisy-images/27224.jpg
#   inflating: __MACOSX/noisy-images/._27224.jpg
#   inflating: noisy-images/38304.jpg
#   inflating: __MACOSX/noisy-images/._38304.jpg
#   inflating: noisy-images/23042.jpg
#   inflating: __MACOSX/noisy-images/._23042.jpg
#   inflating: noisy-images/13181.jpg
#   inflating: __MACOSX/noisy-images/._13181.jpg
#   inflating: noisy-images/33251.jpg
#   inflating: __MACOSX/noisy-images/._33251.jpg
#   inflating: noisy-images/25433.jpg
#   inflating: __MACOSX/noisy-images/._25433.jpg
#   inflating: noisy-images/14836.jpg
#   inflating: __MACOSX/noisy-images/._14836.jpg
#   inflating: noisy-images/52863.jpg
#   inflating: __MACOSX/noisy-images/._52863.jpg
#   inflating: noisy-images/8384.jpg
#   inflating: __MACOSX/noisy-images/._8384.jpg
#   inflating: noisy-images/4596.jpg
#   inflating: __MACOSX/noisy-images/._4596.jpg
#   inflating: noisy-images/36301.jpg
#   inflating: __MACOSX/noisy-images/._36301.jpg
#   inflating: noisy-images/39032.jpg
#   inflating: __MACOSX/noisy-images/._39032.jpg
#   inflating: noisy-images/5850.jpg
#   inflating: __MACOSX/noisy-images/._5850.jpg
#   inflating: noisy-images/26112.jpg
#   inflating: __MACOSX/noisy-images/._26112.jpg
#   inflating: noisy-images/29221.jpg
#   inflating: __MACOSX/noisy-images/._29221.jpg
#   inflating: noisy-images/30770.jpg
#   inflating: __MACOSX/noisy-images/._30770.jpg
#   inflating: noisy-images/11966.jpg
#   inflating: __MACOSX/noisy-images/._11966.jpg
#   inflating: noisy-images/57933.jpg
#   inflating: __MACOSX/noisy-images/._57933.jpg
#   inflating: noisy-images/5688.jpg
#   inflating: __MACOSX/noisy-images/._5688.jpg
#   inflating: noisy-images/20563.jpg
#   inflating: __MACOSX/noisy-images/._20563.jpg
#   inflating: noisy-images/52693.jpg
#   inflating: __MACOSX/noisy-images/._52693.jpg
#   inflating: noisy-images/43946.jpg
#   inflating: __MACOSX/noisy-images/._43946.jpg
#   inflating: noisy-images/6381.jpg
#   inflating: __MACOSX/noisy-images/._6381.jpg
#   inflating: noisy-images/34516.jpg
#   inflating: __MACOSX/noisy-images/._34516.jpg
#   inflating: noisy-images/33279.jpg
#   inflating: __MACOSX/noisy-images/._33279.jpg
#   inflating: noisy-images/24705.jpg
#   inflating: __MACOSX/noisy-images/._24705.jpg
#   inflating: noisy-images/32167.jpg
#   inflating: __MACOSX/noisy-images/._32167.jpg
#   inflating: noisy-images/22374.jpg
#   inflating: __MACOSX/noisy-images/._22374.jpg
#   inflating: noisy-images/55842.jpg
#   inflating: __MACOSX/noisy-images/._55842.jpg
#   inflating: noisy-images/32601.jpg
#   inflating: __MACOSX/noisy-images/._32601.jpg
#   inflating: noisy-images/54584.jpg
#   inflating: __MACOSX/noisy-images/._54584.jpg
#   inflating: noisy-images/7921.jpg
#   inflating: __MACOSX/noisy-images/._7921.jpg
#   inflating: noisy-images/45489.jpg
#   inflating: __MACOSX/noisy-images/._45489.jpg
#   inflating: noisy-images/34270.jpg
#   inflating: __MACOSX/noisy-images/._34270.jpg
#   inflating: noisy-images/37779.jpg
#   inflating: __MACOSX/noisy-images/._37779.jpg
#   inflating: noisy-images/46180.jpg
#   inflating: __MACOSX/noisy-images/._46180.jpg
#   inflating: noisy-images/20205.jpg
#   inflating: __MACOSX/noisy-images/._20205.jpg
#   inflating: noisy-images/56393.jpg
#   inflating: __MACOSX/noisy-images/._56393.jpg
#   inflating: noisy-images/2681.jpg
#   inflating: __MACOSX/noisy-images/._2681.jpg
#   inflating: noisy-images/28659.jpg
#   inflating: __MACOSX/noisy-images/._28659.jpg
#   inflating: noisy-images/26674.jpg
#   inflating: __MACOSX/noisy-images/._26674.jpg
#   inflating: noisy-images/18942.jpg
#   inflating: __MACOSX/noisy-images/._18942.jpg
#   inflating: noisy-images/29547.jpg
#   inflating: __MACOSX/noisy-images/._29547.jpg
#   inflating: noisy-images/31308.jpg
#   inflating: __MACOSX/noisy-images/._31308.jpg
#   inflating: noisy-images/19484.jpg
#   inflating: __MACOSX/noisy-images/._19484.jpg
#   inflating: noisy-images/36467.jpg
#   inflating: __MACOSX/noisy-images/._36467.jpg
#   inflating: noisy-images/2859.jpg
#   inflating: __MACOSX/noisy-images/._2859.jpg
#   inflating: noisy-images/41837.jpg
#   inflating: __MACOSX/noisy-images/._41837.jpg
#   inflating: noisy-images/28881.jpg
#   inflating: __MACOSX/noisy-images/._28881.jpg
#   inflating: noisy-images/39754.jpg
#   inflating: __MACOSX/noisy-images/._39754.jpg
#   inflating: noisy-images/20211.jpg
#   inflating: __MACOSX/noisy-images/._20211.jpg
#   inflating: noisy-images/2695.jpg
#   inflating: __MACOSX/noisy-images/._2695.jpg
#   inflating: noisy-images/30002.jpg
#   inflating: __MACOSX/noisy-images/._30002.jpg
#   inflating: noisy-images/18956.jpg
#   inflating: __MACOSX/noisy-images/._18956.jpg
#   inflating: noisy-images/57099.jpg
#   inflating: __MACOSX/noisy-images/._57099.jpg
#   inflating: noisy-images/26660.jpg
#   inflating: __MACOSX/noisy-images/._26660.jpg
#   inflating: noisy-images/29553.jpg
#   inflating: __MACOSX/noisy-images/._29553.jpg
#   inflating: noisy-images/36473.jpg
#   inflating: __MACOSX/noisy-images/._36473.jpg
#   inflating: noisy-images/19490.jpg
#   inflating: __MACOSX/noisy-images/._19490.jpg
#   inflating: noisy-images/39740.jpg
#   inflating: __MACOSX/noisy-images/._39740.jpg
#   inflating: noisy-images/28895.jpg
#   inflating: __MACOSX/noisy-images/._28895.jpg
#   inflating: noisy-images/22406.jpg
#   inflating: __MACOSX/noisy-images/._22406.jpg
#   inflating: noisy-images/55856.jpg
#   inflating: __MACOSX/noisy-images/._55856.jpg
#   inflating: noisy-images/44783.jpg
#   inflating: __MACOSX/noisy-images/._44783.jpg
#   inflating: noisy-images/13803.jpg
#   inflating: __MACOSX/noisy-images/._13803.jpg
#   inflating: noisy-images/9918.jpg
#   inflating: __MACOSX/noisy-images/._9918.jpg
#   inflating: noisy-images/32615.jpg
#   inflating: __MACOSX/noisy-images/._32615.jpg
#   inflating: noisy-images/25369.jpg
#   inflating: __MACOSX/noisy-images/._25369.jpg
#   inflating: noisy-images/54590.jpg
#   inflating: __MACOSX/noisy-images/._54590.jpg
#   inflating: noisy-images/7935.jpg
#   inflating: __MACOSX/noisy-images/._7935.jpg
#   inflating: noisy-images/24077.jpg
#   inflating: __MACOSX/noisy-images/._24077.jpg
#   inflating: noisy-images/23718.jpg
#   inflating: __MACOSX/noisy-images/._23718.jpg
#   inflating: noisy-images/34264.jpg
#   inflating: __MACOSX/noisy-images/._34264.jpg
#   inflating: noisy-images/43952.jpg
#   inflating: __MACOSX/noisy-images/._43952.jpg
#   inflating: noisy-images/52687.jpg
#   inflating: __MACOSX/noisy-images/._52687.jpg
#   inflating: noisy-images/6395.jpg
#   inflating: __MACOSX/noisy-images/._6395.jpg
#   inflating: noisy-images/24711.jpg
#   inflating: __MACOSX/noisy-images/._24711.jpg
#   inflating: noisy-images/32173.jpg
#   inflating: __MACOSX/noisy-images/._32173.jpg
#   inflating: noisy-images/22360.jpg
#   inflating: __MACOSX/noisy-images/._22360.jpg
#   inflating: noisy-images/53599.jpg
#   inflating: __MACOSX/noisy-images/._53599.jpg
#   inflating: noisy-images/36315.jpg
#   inflating: __MACOSX/noisy-images/._36315.jpg
#   inflating: noisy-images/4582.jpg
#   inflating: __MACOSX/noisy-images/._4582.jpg
#   inflating: noisy-images/39026.jpg
#   inflating: __MACOSX/noisy-images/._39026.jpg
#   inflating: noisy-images/21669.jpg
#   inflating: __MACOSX/noisy-images/._21669.jpg
#   inflating: noisy-images/26106.jpg
#   inflating: __MACOSX/noisy-images/._26106.jpg
#   inflating: noisy-images/5844.jpg
#   inflating: __MACOSX/noisy-images/._5844.jpg
#   inflating: noisy-images/29235.jpg
#   inflating: __MACOSX/noisy-images/._29235.jpg
#   inflating: noisy-images/27218.jpg
#   inflating: __MACOSX/noisy-images/._27218.jpg
#   inflating: noisy-images/48807.jpg
#   inflating: __MACOSX/noisy-images/._48807.jpg
#   inflating: noisy-images/30764.jpg
#   inflating: __MACOSX/noisy-images/._30764.jpg
#   inflating: noisy-images/11972.jpg
#   inflating: __MACOSX/noisy-images/._11972.jpg
#   inflating: noisy-images/27797.jpg
#   inflating: __MACOSX/noisy-images/._27797.jpg
#   inflating: noisy-images/18567.jpg
#   inflating: __MACOSX/noisy-images/._18567.jpg
#   inflating: noisy-images/37584.jpg
#   inflating: __MACOSX/noisy-images/._37584.jpg
#   inflating: noisy-images/29962.jpg
#   inflating: __MACOSX/noisy-images/._29962.jpg
#   inflating: noisy-images/17654.jpg
#   inflating: __MACOSX/noisy-images/._17654.jpg
#   inflating: noisy-images/51601.jpg
#   inflating: __MACOSX/noisy-images/._51601.jpg
#   inflating: noisy-images/47063.jpg
#   inflating: __MACOSX/noisy-images/._47063.jpg
#   inflating: noisy-images/19679.jpg
#   inflating: __MACOSX/noisy-images/._19679.jpg
#   inflating: noisy-images/11225.jpg
#   inflating: __MACOSX/noisy-images/._11225.jpg
#   inflating: noisy-images/26489.jpg
#   inflating: __MACOSX/noisy-images/._26489.jpg
#   inflating: noisy-images/58143.jpg
#   inflating: __MACOSX/noisy-images/._58143.jpg
#   inflating: noisy-images/3762.jpg
#   inflating: __MACOSX/noisy-images/._3762.jpg
#   inflating: noisy-images/43205.jpg
#   inflating: __MACOSX/noisy-images/._43205.jpg
#   inflating: noisy-images/25180.jpg
#   inflating: __MACOSX/noisy-images/._25180.jpg
#   inflating: noisy-images/15043.jpg
#   inflating: __MACOSX/noisy-images/._15043.jpg
#   inflating: noisy-images/53016.jpg
#   inflating: __MACOSX/noisy-images/._53016.jpg
#   inflating: noisy-images/7504.jpg
#   inflating: __MACOSX/noisy-images/._7504.jpg
#   inflating: noisy-images/52308.jpg
#   inflating: __MACOSX/noisy-images/._52308.jpg
#   inflating: noisy-images/9529.jpg
#   inflating: __MACOSX/noisy-images/._9529.jpg
#   inflating: noisy-images/22837.jpg
#   inflating: __MACOSX/noisy-images/._22837.jpg
#   inflating: noisy-images/13432.jpg
#   inflating: __MACOSX/noisy-images/._13432.jpg
#   inflating: noisy-images/55467.jpg
#   inflating: __MACOSX/noisy-images/._55467.jpg
#   inflating: noisy-images/1613.jpg
#   inflating: __MACOSX/noisy-images/._1613.jpg
#   inflating: noisy-images/33084.jpg
#   inflating: __MACOSX/noisy-images/._33084.jpg
#   inflating: noisy-images/13354.jpg
#   inflating: __MACOSX/noisy-images/._13354.jpg
#   inflating: noisy-images/55301.jpg
#   inflating: __MACOSX/noisy-images/._55301.jpg
#   inflating: noisy-images/23297.jpg
#   inflating: __MACOSX/noisy-images/._23297.jpg
#   inflating: noisy-images/45112.jpg
#   inflating: __MACOSX/noisy-images/._45112.jpg
#   inflating: noisy-images/8151.jpg
#   inflating: __MACOSX/noisy-images/._8151.jpg
#   inflating: noisy-images/53770.jpg
#   inflating: __MACOSX/noisy-images/._53770.jpg
#   inflating: noisy-images/22189.jpg
#   inflating: __MACOSX/noisy-images/._22189.jpg
#   inflating: noisy-images/7262.jpg
#   inflating: __MACOSX/noisy-images/._7262.jpg
#   inflating: noisy-images/43563.jpg
#   inflating: __MACOSX/noisy-images/._43563.jpg
#   inflating: noisy-images/34933.jpg
#   inflating: __MACOSX/noisy-images/._34933.jpg
#   inflating: noisy-images/11543.jpg
#   inflating: __MACOSX/noisy-images/._11543.jpg
#   inflating: noisy-images/57516.jpg
#   inflating: __MACOSX/noisy-images/._57516.jpg
#   inflating: noisy-images/58625.jpg
#   inflating: __MACOSX/noisy-images/._58625.jpg
#   inflating: noisy-images/31693.jpg
#   inflating: __MACOSX/noisy-images/._31693.jpg
#   inflating: noisy-images/20946.jpg
#   inflating: __MACOSX/noisy-images/._20946.jpg
#   inflating: noisy-images/10885.jpg
#   inflating: __MACOSX/noisy-images/._10885.jpg
#   inflating: noisy-images/21480.jpg
#   inflating: __MACOSX/noisy-images/._21480.jpg
#   inflating: noisy-images/50279.jpg
#   inflating: __MACOSX/noisy-images/._50279.jpg
#   inflating: noisy-images/48436.jpg
#   inflating: __MACOSX/noisy-images/._48436.jpg
#   inflating: noisy-images/18201.jpg
#   inflating: __MACOSX/noisy-images/._18201.jpg
#   inflating: noisy-images/5475.jpg
#   inflating: __MACOSX/noisy-images/._5475.jpg
#   inflating: noisy-images/49728.jpg
#   inflating: __MACOSX/noisy-images/._49728.jpg
#   inflating: noisy-images/17132.jpg
#   inflating: __MACOSX/noisy-images/._17132.jpg
#   inflating: noisy-images/51167.jpg
#   inflating: __MACOSX/noisy-images/._51167.jpg
#   inflating: noisy-images/56608.jpg
#   inflating: __MACOSX/noisy-images/._56608.jpg
#   inflating: noisy-images/57502.jpg
#   inflating: __MACOSX/noisy-images/._57502.jpg
#   inflating: noisy-images/11557.jpg
#   inflating: __MACOSX/noisy-images/._11557.jpg
#   inflating: noisy-images/20952.jpg
#   inflating: __MACOSX/noisy-images/._20952.jpg
#   inflating: noisy-images/31687.jpg
#   inflating: __MACOSX/noisy-images/._31687.jpg
#   inflating: noisy-images/48422.jpg
#   inflating: __MACOSX/noisy-images/._48422.jpg
#   inflating: noisy-images/21494.jpg
#   inflating: __MACOSX/noisy-images/._21494.jpg
#   inflating: noisy-images/5461.jpg
#   inflating: __MACOSX/noisy-images/._5461.jpg
#   inflating: noisy-images/18215.jpg
#   inflating: __MACOSX/noisy-images/._18215.jpg
#   inflating: noisy-images/51173.jpg
#   inflating: __MACOSX/noisy-images/._51173.jpg
#   inflating: noisy-images/17126.jpg
#   inflating: __MACOSX/noisy-images/._17126.jpg
#   inflating: noisy-images/10649.jpg
#   inflating: __MACOSX/noisy-images/._10649.jpg
#   inflating: noisy-images/41360.jpg
#   inflating: __MACOSX/noisy-images/._41360.jpg
#   inflating: noisy-images/30599.jpg
#   inflating: __MACOSX/noisy-images/._30599.jpg
#   inflating: noisy-images/33090.jpg
#   inflating: __MACOSX/noisy-images/._33090.jpg
#   inflating: noisy-images/1607.jpg
#   inflating: __MACOSX/noisy-images/._1607.jpg
#   inflating: noisy-images/42669.jpg
#   inflating: __MACOSX/noisy-images/._42669.jpg
#   inflating: noisy-images/55315.jpg
#   inflating: __MACOSX/noisy-images/._55315.jpg
#   inflating: noisy-images/13340.jpg
#   inflating: __MACOSX/noisy-images/._13340.jpg
#   inflating: noisy-images/23283.jpg
#   inflating: __MACOSX/noisy-images/._23283.jpg
#   inflating: noisy-images/6168.jpg
#   inflating: __MACOSX/noisy-images/._6168.jpg
#   inflating: noisy-images/53764.jpg
#   inflating: __MACOSX/noisy-images/._53764.jpg
#   inflating: noisy-images/15731.jpg
#   inflating: __MACOSX/noisy-images/._15731.jpg
#   inflating: noisy-images/8145.jpg
#   inflating: __MACOSX/noisy-images/._8145.jpg
#   inflating: noisy-images/44218.jpg
#   inflating: __MACOSX/noisy-images/._44218.jpg
#   inflating: noisy-images/7276.jpg
#   inflating: __MACOSX/noisy-images/._7276.jpg
#   inflating: noisy-images/43577.jpg
#   inflating: __MACOSX/noisy-images/._43577.jpg
#   inflating: noisy-images/34927.jpg
#   inflating: __MACOSX/noisy-images/._34927.jpg
#   inflating: noisy-images/43211.jpg
#   inflating: __MACOSX/noisy-images/._43211.jpg
#   inflating: noisy-images/25194.jpg
#   inflating: __MACOSX/noisy-images/._25194.jpg
#   inflating: noisy-images/53002.jpg
#   inflating: __MACOSX/noisy-images/._53002.jpg
#   inflating: noisy-images/15057.jpg
#   inflating: __MACOSX/noisy-images/._15057.jpg
#   inflating: noisy-images/8623.jpg
#   inflating: __MACOSX/noisy-images/._8623.jpg
#   inflating: noisy-images/7510.jpg
#   inflating: __MACOSX/noisy-images/._7510.jpg
#   inflating: noisy-images/14349.jpg
#   inflating: __MACOSX/noisy-images/._14349.jpg
#   inflating: noisy-images/34099.jpg
#   inflating: __MACOSX/noisy-images/._34099.jpg
#   inflating: noisy-images/45660.jpg
#   inflating: __MACOSX/noisy-images/._45660.jpg
#   inflating: noisy-images/22823.jpg
#   inflating: __MACOSX/noisy-images/._22823.jpg
#   inflating: noisy-images/55473.jpg
#   inflating: __MACOSX/noisy-images/._55473.jpg
#   inflating: noisy-images/13426.jpg
#   inflating: __MACOSX/noisy-images/._13426.jpg
#   inflating: noisy-images/27783.jpg
#   inflating: __MACOSX/noisy-images/._27783.jpg
#   inflating: noisy-images/59249.jpg
#   inflating: __MACOSX/noisy-images/._59249.jpg
#   inflating: noisy-images/41406.jpg
#   inflating: __MACOSX/noisy-images/._41406.jpg
#   inflating: noisy-images/37590.jpg
#   inflating: __MACOSX/noisy-images/._37590.jpg
#   inflating: noisy-images/18573.jpg
#   inflating: __MACOSX/noisy-images/._18573.jpg
#   inflating: noisy-images/51615.jpg
#   inflating: __MACOSX/noisy-images/._51615.jpg
#   inflating: noisy-images/17640.jpg
#   inflating: __MACOSX/noisy-images/._17640.jpg
#   inflating: noisy-images/4019.jpg
#   inflating: __MACOSX/noisy-images/._4019.jpg
#   inflating: noisy-images/47077.jpg
#   inflating: __MACOSX/noisy-images/._47077.jpg
#   inflating: noisy-images/48344.jpg
#   inflating: __MACOSX/noisy-images/._48344.jpg
#   inflating: noisy-images/57264.jpg
#   inflating: __MACOSX/noisy-images/._57264.jpg
#   inflating: noisy-images/11231.jpg
#   inflating: __MACOSX/noisy-images/._11231.jpg
#   inflating: noisy-images/3776.jpg
#   inflating: __MACOSX/noisy-images/._3776.jpg
#   inflating: noisy-images/58157.jpg
#   inflating: __MACOSX/noisy-images/._58157.jpg
#   inflating: noisy-images/17898.jpg
#   inflating: __MACOSX/noisy-images/._17898.jpg
#   inflating: noisy-images/45890.jpg
#   inflating: __MACOSX/noisy-images/._45890.jpg
#   inflating: noisy-images/12710.jpg
#   inflating: __MACOSX/noisy-images/._12710.jpg
#   inflating: noisy-images/43239.jpg
#   inflating: __MACOSX/noisy-images/._43239.jpg
#   inflating: noisy-images/44556.jpg
#   inflating: __MACOSX/noisy-images/._44556.jpg
#   inflating: noisy-images/7538.jpg
#   inflating: __MACOSX/noisy-images/._7538.jpg
#   inflating: noisy-images/33906.jpg
#   inflating: __MACOSX/noisy-images/._33906.jpg
#   inflating: noisy-images/45648.jpg
#   inflating: __MACOSX/noisy-images/._45648.jpg
#   inflating: noisy-images/6626.jpg
#   inflating: __MACOSX/noisy-images/._6626.jpg
#   inflating: noisy-images/52334.jpg
#   inflating: __MACOSX/noisy-images/._52334.jpg
#   inflating: noisy-images/14361.jpg
#   inflating: __MACOSX/noisy-images/._14361.jpg
#   inflating: noisy-images/42127.jpg
#   inflating: __MACOSX/noisy-images/._42127.jpg
#   inflating: noisy-images/28498.jpg
#   inflating: __MACOSX/noisy-images/._28498.jpg
#   inflating: noisy-images/59261.jpg
#   inflating: __MACOSX/noisy-images/._59261.jpg
#   inflating: noisy-images/10107.jpg
#   inflating: __MACOSX/noisy-images/._10107.jpg
#   inflating: noisy-images/17668.jpg
#   inflating: __MACOSX/noisy-images/._17668.jpg
#   inflating: noisy-images/3986.jpg
#   inflating: __MACOSX/noisy-images/._3986.jpg
#   inflating: noisy-images/50523.jpg
#   inflating: __MACOSX/noisy-images/._50523.jpg
#   inflating: noisy-images/39595.jpg
#   inflating: __MACOSX/noisy-images/._39595.jpg
#   inflating: noisy-images/4031.jpg
#   inflating: __MACOSX/noisy-images/._4031.jpg
#   inflating: noisy-images/19645.jpg
#   inflating: __MACOSX/noisy-images/._19645.jpg
#   inflating: noisy-images/27973.jpg
#   inflating: __MACOSX/noisy-images/._27973.jpg
#   inflating: noisy-images/29786.jpg
#   inflating: __MACOSX/noisy-images/._29786.jpg
#   inflating: noisy-images/16210.jpg
#   inflating: __MACOSX/noisy-images/._16210.jpg
#   inflating: noisy-images/4757.jpg
#   inflating: __MACOSX/noisy-images/._4757.jpg
#   inflating: noisy-images/19123.jpg
#   inflating: __MACOSX/noisy-images/._19123.jpg
#   inflating: noisy-images/49714.jpg
#   inflating: __MACOSX/noisy-images/._49714.jpg
#   inflating: noisy-images/31877.jpg
#   inflating: __MACOSX/noisy-images/._31877.jpg
#   inflating: noisy-images/46427.jpg
#   inflating: __MACOSX/noisy-images/._46427.jpg
#   inflating: noisy-images/5449.jpg
#   inflating: __MACOSX/noisy-images/._5449.jpg
#   inflating: noisy-images/2326.jpg
#   inflating: __MACOSX/noisy-images/._2326.jpg
#   inflating: noisy-images/41348.jpg
#   inflating: __MACOSX/noisy-images/._41348.jpg
#   inflating: noisy-images/59507.jpg
#   inflating: __MACOSX/noisy-images/._59507.jpg
#   inflating: noisy-images/10661.jpg
#   inflating: __MACOSX/noisy-images/._10661.jpg
#   inflating: noisy-images/13368.jpg
#   inflating: __MACOSX/noisy-images/._13368.jpg
#   inflating: noisy-images/42641.jpg
#   inflating: __MACOSX/noisy-images/._42641.jpg
#   inflating: noisy-images/53994.jpg
#   inflating: __MACOSX/noisy-images/._53994.jpg
#   inflating: noisy-images/6140.jpg
#   inflating: __MACOSX/noisy-images/._6140.jpg
#   inflating: noisy-images/52452.jpg
#   inflating: __MACOSX/noisy-images/._52452.jpg
#   inflating: noisy-images/9273.jpg
#   inflating: __MACOSX/noisy-images/._9273.jpg
#   inflating: noisy-images/44230.jpg
#   inflating: __MACOSX/noisy-images/._44230.jpg
#   inflating: noisy-images/15719.jpg
#   inflating: __MACOSX/noisy-images/._15719.jpg
#   inflating: noisy-images/42899.jpg
#   inflating: __MACOSX/noisy-images/._42899.jpg
#   inflating: noisy-images/12076.jpg
#   inflating: __MACOSX/noisy-images/._12076.jpg
#   inflating: noisy-images/42655.jpg
#   inflating: __MACOSX/noisy-images/._42655.jpg
#   inflating: noisy-images/6154.jpg
#   inflating: __MACOSX/noisy-images/._6154.jpg
#   inflating: noisy-images/9267.jpg
#   inflating: __MACOSX/noisy-images/._9267.jpg
#   inflating: noisy-images/52446.jpg
#   inflating: __MACOSX/noisy-images/._52446.jpg
#   inflating: noisy-images/44224.jpg
#   inflating: __MACOSX/noisy-images/._44224.jpg
#   inflating: noisy-images/12062.jpg
#   inflating: __MACOSX/noisy-images/._12062.jpg
#   inflating: noisy-images/16204.jpg
#   inflating: __MACOSX/noisy-images/._16204.jpg
#   inflating: noisy-images/19137.jpg
#   inflating: __MACOSX/noisy-images/._19137.jpg
#   inflating: noisy-images/4743.jpg
#   inflating: __MACOSX/noisy-images/._4743.jpg
#   inflating: noisy-images/31863.jpg
#   inflating: __MACOSX/noisy-images/._31863.jpg
#   inflating: noisy-images/49700.jpg
#   inflating: __MACOSX/noisy-images/._49700.jpg
#   inflating: noisy-images/46433.jpg
#   inflating: __MACOSX/noisy-images/._46433.jpg
#   inflating: noisy-images/18229.jpg
#   inflating: __MACOSX/noisy-images/._18229.jpg
#   inflating: noisy-images/59513.jpg
#   inflating: __MACOSX/noisy-images/._59513.jpg
#   inflating: noisy-images/2332.jpg
#   inflating: __MACOSX/noisy-images/._2332.jpg
#   inflating: noisy-images/10675.jpg
#   inflating: __MACOSX/noisy-images/._10675.jpg
#   inflating: noisy-images/59275.jpg
#   inflating: __MACOSX/noisy-images/._59275.jpg
#   inflating: noisy-images/10113.jpg
#   inflating: __MACOSX/noisy-images/._10113.jpg
#   inflating: noisy-images/19889.jpg
#   inflating: __MACOSX/noisy-images/._19889.jpg
#   inflating: noisy-images/56146.jpg
#   inflating: __MACOSX/noisy-images/._56146.jpg
#   inflating: noisy-images/51629.jpg
#   inflating: __MACOSX/noisy-images/._51629.jpg
#   inflating: noisy-images/3992.jpg
#   inflating: __MACOSX/noisy-images/._3992.jpg
#   inflating: noisy-images/49066.jpg
#   inflating: __MACOSX/noisy-images/._49066.jpg
#   inflating: noisy-images/48378.jpg
#   inflating: __MACOSX/noisy-images/._48378.jpg
#   inflating: noisy-images/39581.jpg
#   inflating: __MACOSX/noisy-images/._39581.jpg
#   inflating: noisy-images/27967.jpg
#   inflating: __MACOSX/noisy-images/._27967.jpg
#   inflating: noisy-images/19651.jpg
#   inflating: __MACOSX/noisy-images/._19651.jpg
#   inflating: noisy-images/4025.jpg
#   inflating: __MACOSX/noisy-images/._4025.jpg
#   inflating: noisy-images/38847.jpg
#   inflating: __MACOSX/noisy-images/._38847.jpg
#   inflating: noisy-images/57258.jpg
#   inflating: __MACOSX/noisy-images/._57258.jpg
#   inflating: noisy-images/12704.jpg
#   inflating: __MACOSX/noisy-images/._12704.jpg
#   inflating: noisy-images/45884.jpg
#   inflating: __MACOSX/noisy-images/._45884.jpg
#   inflating: noisy-images/54989.jpg
#   inflating: __MACOSX/noisy-images/._54989.jpg
#   inflating: noisy-images/6632.jpg
#   inflating: __MACOSX/noisy-images/._6632.jpg
#   inflating: noisy-images/9501.jpg
#   inflating: __MACOSX/noisy-images/._9501.jpg
#   inflating: noisy-images/14375.jpg
#   inflating: __MACOSX/noisy-images/._14375.jpg
#   inflating: noisy-images/52320.jpg
#   inflating: __MACOSX/noisy-images/._52320.jpg
#   inflating: noisy-images/42133.jpg
#   inflating: __MACOSX/noisy-images/._42133.jpg
#   inflating: noisy-images/23532.jpg
#   inflating: __MACOSX/noisy-images/._23532.jpg
#   inflating: noisy-images/12937.jpg
#   inflating: __MACOSX/noisy-images/._12937.jpg
#   inflating: noisy-images/33721.jpg
#   inflating: __MACOSX/noisy-images/._33721.jpg
#   inflating: noisy-images/25143.jpg
#   inflating: __MACOSX/noisy-images/._25143.jpg
#   inflating: noisy-images/6801.jpg
#   inflating: __MACOSX/noisy-images/._6801.jpg
#   inflating: noisy-images/15080.jpg
#   inflating: __MACOSX/noisy-images/._15080.jpg
#   inflating: noisy-images/35350.jpg
#   inflating: __MACOSX/noisy-images/._35350.jpg
#   inflating: noisy-images/48393.jpg
#   inflating: __MACOSX/noisy-images/._48393.jpg
#   inflating: noisy-images/21325.jpg
#   inflating: __MACOSX/noisy-images/._21325.jpg
#   inflating: noisy-images/58180.jpg
#   inflating: __MACOSX/noisy-images/._58180.jpg
#   inflating: noisy-images/29779.jpg
#   inflating: __MACOSX/noisy-images/._29779.jpg
#   inflating: noisy-images/27754.jpg
#   inflating: __MACOSX/noisy-images/._27754.jpg
#   inflating: noisy-images/19862.jpg
#   inflating: __MACOSX/noisy-images/._19862.jpg
#   inflating: noisy-images/28467.jpg
#   inflating: __MACOSX/noisy-images/._28467.jpg
#   inflating: noisy-images/30228.jpg
#   inflating: __MACOSX/noisy-images/._30228.jpg
#   inflating: noisy-images/37547.jpg
#   inflating: __MACOSX/noisy-images/._37547.jpg
#   inflating: noisy-images/3979.jpg
#   inflating: __MACOSX/noisy-images/._3979.jpg
#   inflating: noisy-images/17697.jpg
#   inflating: __MACOSX/noisy-images/._17697.jpg
#   inflating: noisy-images/38674.jpg
#   inflating: __MACOSX/noisy-images/._38674.jpg
#   inflating: noisy-images/37221.jpg
#   inflating: __MACOSX/noisy-images/._37221.jpg
#   inflating: noisy-images/4970.jpg
#   inflating: __MACOSX/noisy-images/._4970.jpg
#   inflating: noisy-images/27032.jpg
#   inflating: __MACOSX/noisy-images/._27032.jpg
#   inflating: noisy-images/28301.jpg
#   inflating: __MACOSX/noisy-images/._28301.jpg
#   inflating: noisy-images/11580.jpg
#   inflating: __MACOSX/noisy-images/._11580.jpg
#   inflating: noisy-images/49933.jpg
#   inflating: __MACOSX/noisy-images/._49933.jpg
#   inflating: noisy-images/10846.jpg
#   inflating: __MACOSX/noisy-images/._10846.jpg
#   inflating: noisy-images/56813.jpg
#   inflating: __MACOSX/noisy-images/._56813.jpg
#   inflating: noisy-images/21443.jpg
#   inflating: __MACOSX/noisy-images/._21443.jpg
#   inflating: noisy-images/42866.jpg
#   inflating: __MACOSX/noisy-images/._42866.jpg
#   inflating: noisy-images/8192.jpg
#   inflating: __MACOSX/noisy-images/._8192.jpg
#   inflating: noisy-images/35436.jpg
#   inflating: __MACOSX/noisy-images/._35436.jpg
#   inflating: noisy-images/32359.jpg
#   inflating: __MACOSX/noisy-images/._32359.jpg
#   inflating: noisy-images/12089.jpg
#   inflating: __MACOSX/noisy-images/._12089.jpg
#   inflating: noisy-images/25625.jpg
#   inflating: __MACOSX/noisy-images/._25625.jpg
#   inflating: noisy-images/33047.jpg
#   inflating: __MACOSX/noisy-images/._33047.jpg
#   inflating: noisy-images/13397.jpg
#   inflating: __MACOSX/noisy-images/._13397.jpg
#   inflating: noisy-images/23254.jpg
#   inflating: __MACOSX/noisy-images/._23254.jpg
#   inflating: noisy-images/34728.jpg
#   inflating: __MACOSX/noisy-images/._34728.jpg
#   inflating: noisy-images/8186.jpg
#   inflating: __MACOSX/noisy-images/._8186.jpg
#   inflating: noisy-images/42872.jpg
#   inflating: __MACOSX/noisy-images/._42872.jpg
#   inflating: noisy-images/35422.jpg
#   inflating: __MACOSX/noisy-images/._35422.jpg
#   inflating: noisy-images/25631.jpg
#   inflating: __MACOSX/noisy-images/._25631.jpg
#   inflating: noisy-images/33053.jpg
#   inflating: __MACOSX/noisy-images/._33053.jpg
#   inflating: noisy-images/13383.jpg
#   inflating: __MACOSX/noisy-images/._13383.jpg
#   inflating: noisy-images/23240.jpg
#   inflating: __MACOSX/noisy-images/._23240.jpg
#   inflating: noisy-images/37235.jpg
#   inflating: __MACOSX/noisy-images/._37235.jpg
#   inflating: noisy-images/27026.jpg
#   inflating: __MACOSX/noisy-images/._27026.jpg
#   inflating: noisy-images/4964.jpg
#   inflating: __MACOSX/noisy-images/._4964.jpg
#   inflating: noisy-images/28315.jpg
#   inflating: __MACOSX/noisy-images/._28315.jpg
#   inflating: noisy-images/11594.jpg
#   inflating: __MACOSX/noisy-images/._11594.jpg
#   inflating: noisy-images/26338.jpg
#   inflating: __MACOSX/noisy-images/._26338.jpg
#   inflating: noisy-images/49927.jpg
#   inflating: __MACOSX/noisy-images/._49927.jpg
#   inflating: noisy-images/31644.jpg
#   inflating: __MACOSX/noisy-images/._31644.jpg
#   inflating: noisy-images/56807.jpg
#   inflating: __MACOSX/noisy-images/._56807.jpg
#   inflating: noisy-images/10852.jpg
#   inflating: __MACOSX/noisy-images/._10852.jpg
#   inflating: noisy-images/39218.jpg
#   inflating: __MACOSX/noisy-images/._39218.jpg
#   inflating: noisy-images/27998.jpg
#   inflating: __MACOSX/noisy-images/._27998.jpg
#   inflating: noisy-images/21331.jpg
#   inflating: __MACOSX/noisy-images/._21331.jpg
#   inflating: noisy-images/48387.jpg
#   inflating: __MACOSX/noisy-images/._48387.jpg
#   inflating: noisy-images/58194.jpg
#   inflating: __MACOSX/noisy-images/._58194.jpg
#   inflating: noisy-images/31122.jpg
#   inflating: __MACOSX/noisy-images/._31122.jpg
#   inflating: noisy-images/19876.jpg
#   inflating: __MACOSX/noisy-images/._19876.jpg
#   inflating: noisy-images/36895.jpg
#   inflating: __MACOSX/noisy-images/._36895.jpg
#   inflating: noisy-images/27740.jpg
#   inflating: __MACOSX/noisy-images/._27740.jpg
#   inflating: noisy-images/28473.jpg
#   inflating: __MACOSX/noisy-images/._28473.jpg
#   inflating: noisy-images/38660.jpg
#   inflating: __MACOSX/noisy-images/._38660.jpg
#   inflating: noisy-images/49099.jpg
#   inflating: __MACOSX/noisy-images/._49099.jpg
#   inflating: noisy-images/17683.jpg
#   inflating: __MACOSX/noisy-images/._17683.jpg
#   inflating: noisy-images/23526.jpg
#   inflating: __MACOSX/noisy-images/._23526.jpg
#   inflating: noisy-images/54976.jpg
#   inflating: __MACOSX/noisy-images/._54976.jpg
#   inflating: noisy-images/12923.jpg
#   inflating: __MACOSX/noisy-images/._12923.jpg
#   inflating: noisy-images/8838.jpg
#   inflating: __MACOSX/noisy-images/._8838.jpg
#   inflating: noisy-images/33735.jpg
#   inflating: __MACOSX/noisy-images/._33735.jpg
#   inflating: noisy-images/24249.jpg
#   inflating: __MACOSX/noisy-images/._24249.jpg
#   inflating: noisy-images/6815.jpg
#   inflating: __MACOSX/noisy-images/._6815.jpg
#   inflating: noisy-images/25157.jpg
#   inflating: __MACOSX/noisy-images/._25157.jpg
#   inflating: noisy-images/15094.jpg
#   inflating: __MACOSX/noisy-images/._15094.jpg
#   inflating: noisy-images/22638.jpg
#   inflating: __MACOSX/noisy-images/._22638.jpg
#   inflating: noisy-images/21319.jpg
#   inflating: __MACOSX/noisy-images/._21319.jpg
#   inflating: noisy-images/19686.jpg
#   inflating: __MACOSX/noisy-images/._19686.jpg
#   inflating: noisy-images/36665.jpg
#   inflating: __MACOSX/noisy-images/._36665.jpg
#   inflating: noisy-images/51826.jpg
#   inflating: __MACOSX/noisy-images/._51826.jpg
#   inflating: noisy-images/17873.jpg
#   inflating: __MACOSX/noisy-images/._17873.jpg
#   inflating: noisy-images/29745.jpg
#   inflating: __MACOSX/noisy-images/._29745.jpg
#   inflating: noisy-images/26476.jpg
#   inflating: __MACOSX/noisy-images/._26476.jpg
#   inflating: noisy-images/2483.jpg
#   inflating: __MACOSX/noisy-images/._2483.jpg
#   inflating: noisy-images/56191.jpg
#   inflating: __MACOSX/noisy-images/._56191.jpg
#   inflating: noisy-images/27768.jpg
#   inflating: __MACOSX/noisy-images/._27768.jpg
#   inflating: noisy-images/3945.jpg
#   inflating: __MACOSX/noisy-images/._3945.jpg
#   inflating: noisy-images/20007.jpg
#   inflating: __MACOSX/noisy-images/._20007.jpg
#   inflating: noisy-images/38648.jpg
#   inflating: __MACOSX/noisy-images/._38648.jpg
#   inflating: noisy-images/46382.jpg
#   inflating: __MACOSX/noisy-images/._46382.jpg
#   inflating: noisy-images/18598.jpg
#   inflating: __MACOSX/noisy-images/._18598.jpg
#   inflating: noisy-images/34072.jpg
#   inflating: __MACOSX/noisy-images/._34072.jpg
#   inflating: noisy-images/55498.jpg
#   inflating: __MACOSX/noisy-images/._55498.jpg
#   inflating: noisy-images/8810.jpg
#   inflating: __MACOSX/noisy-images/._8810.jpg
#   inflating: noisy-images/32403.jpg
#   inflating: __MACOSX/noisy-images/._32403.jpg
#   inflating: noisy-images/22610.jpg
#   inflating: __MACOSX/noisy-images/._22610.jpg
#   inflating: noisy-images/22176.jpg
#   inflating: __MACOSX/noisy-images/._22176.jpg
#   inflating: noisy-images/25619.jpg
#   inflating: __MACOSX/noisy-images/._25619.jpg
#   inflating: noisy-images/32365.jpg
#   inflating: __MACOSX/noisy-images/._32365.jpg
#   inflating: noisy-images/24507.jpg
#   inflating: __MACOSX/noisy-images/._24507.jpg
#   inflating: noisy-images/42682.jpg
#   inflating: __MACOSX/noisy-images/._42682.jpg
#   inflating: noisy-images/15902.jpg
#   inflating: __MACOSX/noisy-images/._15902.jpg
#   inflating: noisy-images/6183.jpg
#   inflating: __MACOSX/noisy-images/._6183.jpg
#   inflating: noisy-images/23268.jpg
#   inflating: __MACOSX/noisy-images/._23268.jpg
#   inflating: noisy-images/52491.jpg
#   inflating: __MACOSX/noisy-images/._52491.jpg
#   inflating: noisy-images/20761.jpg
#   inflating: __MACOSX/noisy-images/._20761.jpg
#   inflating: noisy-images/58802.jpg
#   inflating: __MACOSX/noisy-images/._58802.jpg
#   inflating: noisy-images/30572.jpg
#   inflating: __MACOSX/noisy-images/._30572.jpg
#   inflating: noisy-images/40095.jpg
#   inflating: __MACOSX/noisy-images/._40095.jpg
#   inflating: noisy-images/29023.jpg
#   inflating: __MACOSX/noisy-images/._29023.jpg
#   inflating: noisy-images/26310.jpg
#   inflating: __MACOSX/noisy-images/._26310.jpg
#   inflating: noisy-images/39230.jpg
#   inflating: __MACOSX/noisy-images/._39230.jpg
#   inflating: noisy-images/50286.jpg
#   inflating: __MACOSX/noisy-images/._50286.jpg
#   inflating: noisy-images/4794.jpg
#   inflating: __MACOSX/noisy-images/._4794.jpg
#   inflating: noisy-images/36103.jpg
#   inflating: __MACOSX/noisy-images/._36103.jpg
#   inflating: noisy-images/58816.jpg
#   inflating: __MACOSX/noisy-images/._58816.jpg
#   inflating: noisy-images/20775.jpg
#   inflating: __MACOSX/noisy-images/._20775.jpg
#   inflating: noisy-images/37209.jpg
#   inflating: __MACOSX/noisy-images/._37209.jpg
# ...
#   inflating: noisy-images/38477.jpg
#   inflating: __MACOSX/noisy-images/._38477.jpg
#   inflating: noisy-images/17494.jpg
#   inflating: __MACOSX/noisy-images/._17494.jpg
#   inflating: noisy-images/20238.jpg
#   inflating: __MACOSX/noisy-images/._20238.jpg
#   inflating: noisy-images/2657.jpg
#   inflating: __MACOSX/noisy-images/._2657.jpg
#   inflating: noisy-images/59076.jpg
#   inflating: __MACOSX/noisy-images/._59076.jpg
#   inflating: noisy-images/46156.jpg
#   inflating: __MACOSX/noisy-images/._46156.jpg
#   inflating: noisy-images/5138.jpg
#   inflating: __MACOSX/noisy-images/._5138.jpg
#   inflating: noisy-images/50734.jpg
#   inflating: __MACOSX/noisy-images/._50734.jpg
#   inflating: noisy-images/28857.jpg
#   inflating: __MACOSX/noisy-images/._28857.jpg
#   inflating: noisy-images/16761.jpg
#   inflating: __MACOSX/noisy-images/._16761.jpg
#   inflating: noisy-images/39782.jpg
#   inflating: __MACOSX/noisy-images/._39782.jpg
#   inflating: noisy-images/4226.jpg
#   inflating: __MACOSX/noisy-images/._4226.jpg
#   inflating: noisy-images/47248.jpg
#   inflating: __MACOSX/noisy-images/._47248.jpg
#   inflating: noisy-images/3549.jpg
#   inflating: __MACOSX/noisy-images/._3549.jpg
#   inflating: noisy-images/40527.jpg
#   inflating: __MACOSX/noisy-images/._40527.jpg
#   inflating: noisy-images/37977.jpg
#   inflating: __MACOSX/noisy-images/._37977.jpg
#   inflating: noisy-images/18994.jpg
#   inflating: __MACOSX/noisy-images/._18994.jpg
#   inflating: noisy-images/12507.jpg
#   inflating: __MACOSX/noisy-images/._12507.jpg
#   inflating: noisy-images/44741.jpg
#   inflating: __MACOSX/noisy-images/._44741.jpg
#   inflating: noisy-images/55894.jpg
#   inflating: __MACOSX/noisy-images/._55894.jpg
#   inflating: noisy-images/15268.jpg
#   inflating: __MACOSX/noisy-images/._15268.jpg
#   inflating: noisy-images/6431.jpg
#   inflating: __MACOSX/noisy-images/._6431.jpg
#   inflating: noisy-images/52123.jpg
#   inflating: __MACOSX/noisy-images/._52123.jpg
#   inflating: noisy-images/14176.jpg
#   inflating: __MACOSX/noisy-images/._14176.jpg
#   inflating: noisy-images/9702.jpg
#   inflating: __MACOSX/noisy-images/._9702.jpg
#   inflating: noisy-images/13619.jpg
#   inflating: __MACOSX/noisy-images/._13619.jpg
#   inflating: noisy-images/44999.jpg
#   inflating: __MACOSX/noisy-images/._44999.jpg
#   inflating: noisy-images/42330.jpg
#   inflating: __MACOSX/noisy-images/._42330.jpg
#   inflating: noisy-images/35806.jpg
#   inflating: __MACOSX/noisy-images/._35806.jpg
#   inflating: noisy-images/45339.jpg
#   inflating: __MACOSX/noisy-images/._45339.jpg
#   inflating: noisy-images/6357.jpg
#   inflating: __MACOSX/noisy-images/._6357.jpg
#   inflating: noisy-images/43990.jpg
#   inflating: __MACOSX/noisy-images/._43990.jpg
#   inflating: noisy-images/14610.jpg
#   inflating: __MACOSX/noisy-images/._14610.jpg
#   inflating: noisy-images/9064.jpg
#   inflating: __MACOSX/noisy-images/._9064.jpg
#   inflating: noisy-images/44027.jpg
#   inflating: __MACOSX/noisy-images/._44027.jpg
#   inflating: noisy-images/7049.jpg
#   inflating: __MACOSX/noisy-images/._7049.jpg
#   inflating: noisy-images/43748.jpg
#   inflating: __MACOSX/noisy-images/._43748.jpg
#   inflating: noisy-images/11768.jpg
#   inflating: __MACOSX/noisy-images/._11768.jpg
#   inflating: noisy-images/5886.jpg
#   inflating: __MACOSX/noisy-images/._5886.jpg
#   inflating: noisy-images/16007.jpg
#   inflating: __MACOSX/noisy-images/._16007.jpg
#   inflating: noisy-images/4540.jpg
#   inflating: __MACOSX/noisy-images/._4540.jpg
#   inflating: noisy-images/19334.jpg
#   inflating: __MACOSX/noisy-images/._19334.jpg
#   inflating: noisy-images/17319.jpg
#   inflating: __MACOSX/noisy-images/._17319.jpg
#   inflating: noisy-images/46630.jpg
#   inflating: __MACOSX/noisy-images/._46630.jpg
#   inflating: noisy-images/2131.jpg
#   inflating: __MACOSX/noisy-images/._2131.jpg
#   inflating: noisy-images/21873.jpg
#   inflating: __MACOSX/noisy-images/._21873.jpg
#   inflating: noisy-images/59710.jpg
#   inflating: __MACOSX/noisy-images/._59710.jpg
#   inflating: noisy-images/56423.jpg
#   inflating: __MACOSX/noisy-images/._56423.jpg
#   inflating: noisy-images/10476.jpg
#   inflating: __MACOSX/noisy-images/._10476.jpg
#   inflating: noisy-images/40255.jpg
#   inflating: __MACOSX/noisy-images/._40255.jpg
#   inflating: noisy-images/5892.jpg
#   inflating: __MACOSX/noisy-images/._5892.jpg
#   inflating: noisy-images/48609.jpg
#   inflating: __MACOSX/noisy-images/._48609.jpg
#   inflating: noisy-images/16013.jpg
#   inflating: __MACOSX/noisy-images/._16013.jpg
#   inflating: noisy-images/50046.jpg
#   inflating: __MACOSX/noisy-images/._50046.jpg
#   inflating: noisy-images/19320.jpg
#   inflating: __MACOSX/noisy-images/._19320.jpg
#   inflating: noisy-images/4554.jpg
#   inflating: __MACOSX/noisy-images/._4554.jpg
#   inflating: noisy-images/49517.jpg
#   inflating: __MACOSX/noisy-images/._49517.jpg
#   inflating: noisy-images/46624.jpg
#   inflating: __MACOSX/noisy-images/._46624.jpg
#   inflating: noisy-images/59704.jpg
#   inflating: __MACOSX/noisy-images/._59704.jpg
#   inflating: noisy-images/2125.jpg
#   inflating: __MACOSX/noisy-images/._2125.jpg
#   inflating: noisy-images/10462.jpg
#   inflating: __MACOSX/noisy-images/._10462.jpg
#   inflating: noisy-images/6343.jpg
#   inflating: __MACOSX/noisy-images/._6343.jpg
#   inflating: noisy-images/9070.jpg
#   inflating: __MACOSX/noisy-images/._9070.jpg
#   inflating: noisy-images/14604.jpg
#   inflating: __MACOSX/noisy-images/._14604.jpg
#   inflating: noisy-images/52651.jpg
#   inflating: __MACOSX/noisy-images/._52651.jpg
#   inflating: noisy-images/12275.jpg
#   inflating: __MACOSX/noisy-images/._12275.jpg
#   inflating: noisy-images/52889.jpg
#   inflating: __MACOSX/noisy-images/._52889.jpg
#   inflating: noisy-images/12513.jpg
#   inflating: __MACOSX/noisy-images/._12513.jpg
#   inflating: noisy-images/54546.jpg
#   inflating: __MACOSX/noisy-images/._54546.jpg
#   inflating: noisy-images/55880.jpg
#   inflating: __MACOSX/noisy-images/._55880.jpg
#   inflating: noisy-images/44755.jpg
#   inflating: __MACOSX/noisy-images/._44755.jpg
#   inflating: noisy-images/8408.jpg
#   inflating: __MACOSX/noisy-images/._8408.jpg
#   inflating: noisy-images/6425.jpg
#   inflating: __MACOSX/noisy-images/._6425.jpg
#   inflating: noisy-images/9716.jpg
#   inflating: __MACOSX/noisy-images/._9716.jpg
#   inflating: noisy-images/14162.jpg
#   inflating: __MACOSX/noisy-images/._14162.jpg
#   inflating: noisy-images/52137.jpg
#   inflating: __MACOSX/noisy-images/._52137.jpg
#   inflating: noisy-images/59062.jpg
#   inflating: __MACOSX/noisy-images/._59062.jpg
#   inflating: noisy-images/10304.jpg
#   inflating: __MACOSX/noisy-images/._10304.jpg
#   inflating: noisy-images/56351.jpg
#   inflating: __MACOSX/noisy-images/._56351.jpg
#   inflating: noisy-images/38488.jpg
#   inflating: __MACOSX/noisy-images/._38488.jpg
#   inflating: noisy-images/18758.jpg
#   inflating: __MACOSX/noisy-images/._18758.jpg
#   inflating: noisy-images/16775.jpg
#   inflating: __MACOSX/noisy-images/._16775.jpg
#   inflating: noisy-images/50720.jpg
#   inflating: __MACOSX/noisy-images/._50720.jpg
#   inflating: noisy-images/4232.jpg
#   inflating: __MACOSX/noisy-images/._4232.jpg
#   inflating: noisy-images/40533.jpg
#   inflating: __MACOSX/noisy-images/._40533.jpg
#   inflating: noisy-images/18980.jpg
#   inflating: __MACOSX/noisy-images/._18980.jpg
#   inflating: noisy-images/37963.jpg
#   inflating: __MACOSX/noisy-images/._37963.jpg
#   inflating: noisy-images/8420.jpg
#   inflating: __MACOSX/noisy-images/._8420.jpg
#   inflating: noisy-images/15254.jpg
#   inflating: __MACOSX/noisy-images/._15254.jpg
#   inflating: noisy-images/35184.jpg
#   inflating: __MACOSX/noisy-images/._35184.jpg
#   inflating: noisy-images/7713.jpg
#   inflating: __MACOSX/noisy-images/._7713.jpg
#   inflating: noisy-images/32833.jpg
#   inflating: __MACOSX/noisy-images/._32833.jpg
#   inflating: noisy-images/24089.jpg
#   inflating: __MACOSX/noisy-images/._24089.jpg
#   inflating: noisy-images/56379.jpg
#   inflating: __MACOSX/noisy-images/._56379.jpg
#   inflating: noisy-images/27580.jpg
#   inflating: __MACOSX/noisy-images/._27580.jpg
#   inflating: noisy-images/41605.jpg
#   inflating: __MACOSX/noisy-images/._41605.jpg
#   inflating: noisy-images/39966.jpg
#   inflating: __MACOSX/noisy-images/._39966.jpg
#   inflating: noisy-images/16985.jpg
#   inflating: __MACOSX/noisy-images/._16985.jpg
#   inflating: noisy-images/18770.jpg
#   inflating: __MACOSX/noisy-images/._18770.jpg
#   inflating: noisy-images/37793.jpg
#   inflating: __MACOSX/noisy-images/._37793.jpg
#   inflating: noisy-images/5104.jpg
#   inflating: __MACOSX/noisy-images/._5104.jpg
#   inflating: noisy-images/17443.jpg
#   inflating: __MACOSX/noisy-images/._17443.jpg
#   inflating: noisy-images/47274.jpg
#   inflating: __MACOSX/noisy-images/._47274.jpg
#   inflating: noisy-images/50708.jpg
#   inflating: __MACOSX/noisy-images/._50708.jpg
#   inflating: noisy-images/48147.jpg
#   inflating: __MACOSX/noisy-images/._48147.jpg
#   inflating: noisy-images/11032.jpg
#   inflating: __MACOSX/noisy-images/._11032.jpg
#   inflating: noisy-images/57067.jpg
#   inflating: __MACOSX/noisy-images/._57067.jpg
#   inflating: noisy-images/3575.jpg
#   inflating: __MACOSX/noisy-images/._3575.jpg
#   inflating: noisy-images/11754.jpg
#   inflating: __MACOSX/noisy-images/._11754.jpg
#   inflating: noisy-images/3213.jpg
#   inflating: __MACOSX/noisy-images/._3213.jpg
#   inflating: noisy-images/47512.jpg
#   inflating: __MACOSX/noisy-images/._47512.jpg
#   inflating: noisy-images/19308.jpg
#   inflating: __MACOSX/noisy-images/._19308.jpg
#   inflating: noisy-images/21697.jpg
#   inflating: __MACOSX/noisy-images/._21697.jpg
#   inflating: noisy-images/30942.jpg
#   inflating: __MACOSX/noisy-images/._30942.jpg
#   inflating: noisy-images/48621.jpg
#   inflating: __MACOSX/noisy-images/._48621.jpg
#   inflating: noisy-images/18016.jpg
#   inflating: __MACOSX/noisy-images/._18016.jpg
#   inflating: noisy-images/5662.jpg
#   inflating: __MACOSX/noisy-images/._5662.jpg
#   inflating: noisy-images/17325.jpg
#   inflating: __MACOSX/noisy-images/._17325.jpg
#   inflating: noisy-images/51370.jpg
#   inflating: __MACOSX/noisy-images/._51370.jpg
#   inflating: noisy-images/20589.jpg
#   inflating: __MACOSX/noisy-images/._20589.jpg
#   inflating: noisy-images/41163.jpg
#   inflating: __MACOSX/noisy-images/._41163.jpg
#   inflating: noisy-images/33293.jpg
#   inflating: __MACOSX/noisy-images/._33293.jpg
#   inflating: noisy-images/13143.jpg
#   inflating: __MACOSX/noisy-images/._13143.jpg
#   inflating: noisy-images/55116.jpg
#   inflating: __MACOSX/noisy-images/._55116.jpg
#   inflating: noisy-images/52679.jpg
#   inflating: __MACOSX/noisy-images/._52679.jpg
#   inflating: noisy-images/9058.jpg
#   inflating: __MACOSX/noisy-images/._9058.jpg
#   inflating: noisy-images/8346.jpg
#   inflating: __MACOSX/noisy-images/._8346.jpg
#   inflating: noisy-images/15532.jpg
#   inflating: __MACOSX/noisy-images/._15532.jpg
#   inflating: noisy-images/53567.jpg
#   inflating: __MACOSX/noisy-images/._53567.jpg
#   inflating: noisy-images/24937.jpg
#   inflating: __MACOSX/noisy-images/._24937.jpg
#   inflating: noisy-images/7075.jpg
#   inflating: __MACOSX/noisy-images/._7075.jpg
#   inflating: noisy-images/33287.jpg
#   inflating: __MACOSX/noisy-images/._33287.jpg
#   inflating: noisy-images/13157.jpg
#   inflating: __MACOSX/noisy-images/._13157.jpg
#   inflating: noisy-images/14638.jpg
#   inflating: __MACOSX/noisy-images/._14638.jpg
#   inflating: noisy-images/23094.jpg
#   inflating: __MACOSX/noisy-images/._23094.jpg
#   inflating: noisy-images/53573.jpg
#   inflating: __MACOSX/noisy-images/._53573.jpg
#   inflating: noisy-images/15526.jpg
#   inflating: __MACOSX/noisy-images/._15526.jpg
#   inflating: noisy-images/8352.jpg
#   inflating: __MACOSX/noisy-images/._8352.jpg
#   inflating: noisy-images/7061.jpg
#   inflating: __MACOSX/noisy-images/._7061.jpg
#   inflating: noisy-images/24923.jpg
#   inflating: __MACOSX/noisy-images/._24923.jpg
#   inflating: noisy-images/43760.jpg
#   inflating: __MACOSX/noisy-images/._43760.jpg
#   inflating: noisy-images/32199.jpg
#   inflating: __MACOSX/noisy-images/._32199.jpg
#   inflating: noisy-images/12249.jpg
#   inflating: __MACOSX/noisy-images/._12249.jpg
#   inflating: noisy-images/11740.jpg
#   inflating: __MACOSX/noisy-images/._11740.jpg
#   inflating: noisy-images/3207.jpg
#   inflating: __MACOSX/noisy-images/._3207.jpg
#   inflating: noisy-images/40269.jpg
#   inflating: __MACOSX/noisy-images/._40269.jpg
#   inflating: noisy-images/4568.jpg
#   inflating: __MACOSX/noisy-images/._4568.jpg
#   inflating: noisy-images/47506.jpg
#   inflating: __MACOSX/noisy-images/._47506.jpg
#   inflating: noisy-images/30956.jpg
#   inflating: __MACOSX/noisy-images/._30956.jpg
#   inflating: noisy-images/21683.jpg
#   inflating: __MACOSX/noisy-images/._21683.jpg
#   inflating: noisy-images/46618.jpg
#   inflating: __MACOSX/noisy-images/._46618.jpg
#   inflating: noisy-images/5676.jpg
#   inflating: __MACOSX/noisy-images/._5676.jpg
#   inflating: noisy-images/18002.jpg
#   inflating: __MACOSX/noisy-images/._18002.jpg
#   inflating: noisy-images/11998.jpg
#   inflating: __MACOSX/noisy-images/._11998.jpg
#   inflating: noisy-images/51364.jpg
#   inflating: __MACOSX/noisy-images/._51364.jpg
#   inflating: noisy-images/17331.jpg
#   inflating: __MACOSX/noisy-images/._17331.jpg
#   inflating: noisy-images/2119.jpg
#   inflating: __MACOSX/noisy-images/._2119.jpg
#   inflating: noisy-images/10338.jpg
#   inflating: __MACOSX/noisy-images/._10338.jpg
#   inflating: noisy-images/27594.jpg
#   inflating: __MACOSX/noisy-images/._27594.jpg
#   inflating: noisy-images/16991.jpg
#   inflating: __MACOSX/noisy-images/._16991.jpg
#   inflating: noisy-images/39972.jpg
#   inflating: __MACOSX/noisy-images/._39972.jpg
#   inflating: noisy-images/41611.jpg
#   inflating: __MACOSX/noisy-images/._41611.jpg
#   inflating: noisy-images/26852.jpg
#   inflating: __MACOSX/noisy-images/._26852.jpg
#   inflating: noisy-images/5110.jpg
#   inflating: __MACOSX/noisy-images/._5110.jpg
#   inflating: noisy-images/37787.jpg
#   inflating: __MACOSX/noisy-images/._37787.jpg
#   inflating: noisy-images/18764.jpg
#   inflating: __MACOSX/noisy-images/._18764.jpg
#   inflating: noisy-images/51402.jpg
#   inflating: __MACOSX/noisy-images/._51402.jpg
#   inflating: noisy-images/17457.jpg
#   inflating: __MACOSX/noisy-images/._17457.jpg
#   inflating: noisy-images/36499.jpg
#   inflating: __MACOSX/noisy-images/._36499.jpg
#   inflating: noisy-images/47260.jpg
#   inflating: __MACOSX/noisy-images/._47260.jpg
#   inflating: noisy-images/48153.jpg
#   inflating: __MACOSX/noisy-images/._48153.jpg
#   inflating: noisy-images/16749.jpg
#   inflating: __MACOSX/noisy-images/._16749.jpg
#   inflating: noisy-images/57073.jpg
#   inflating: __MACOSX/noisy-images/._57073.jpg
#   inflating: noisy-images/11026.jpg
#   inflating: __MACOSX/noisy-images/._11026.jpg
#   inflating: noisy-images/3561.jpg
#   inflating: __MACOSX/noisy-images/._3561.jpg
#   inflating: noisy-images/58340.jpg
#   inflating: __MACOSX/noisy-images/._58340.jpg
#   inflating: noisy-images/43006.jpg
#   inflating: __MACOSX/noisy-images/._43006.jpg
#   inflating: noisy-images/25383.jpg
#   inflating: __MACOSX/noisy-images/._25383.jpg
#   inflating: noisy-images/53215.jpg
#   inflating: __MACOSX/noisy-images/._53215.jpg
#   inflating: noisy-images/15240.jpg
#   inflating: __MACOSX/noisy-images/._15240.jpg
#   inflating: noisy-images/8434.jpg
#   inflating: __MACOSX/noisy-images/._8434.jpg
#   inflating: noisy-images/44769.jpg
#   inflating: __MACOSX/noisy-images/._44769.jpg
#   inflating: noisy-images/7707.jpg
#   inflating: __MACOSX/noisy-images/._7707.jpg
#   inflating: noisy-images/6419.jpg
#   inflating: __MACOSX/noisy-images/._6419.jpg

# %% [markdown]
# # Input train and test data
#
# If you want to try validation data, uncomment the code.

# %%
train_df = pd.read_csv('/content/drive/MyDrive/train.csv')
#train_df, valid_df = train_test_split(train_df, test_size=0.2, random_state=480)

test_df = pd.read_csv('/content/drive/MyDrive/test.csv')

device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

# %% [markdown]
# # Create category dictionary

# %%
category_map = {cat: val for val, cat in enumerate(set(train_df['category']))}
print(category_map)
gender_map = {gender: val for val, gender in enumerate(set(train_df['gender']))}
print(gender_map)
color_map = {color: val for val, color in enumerate(set(train_df['baseColour']))}
print(color_map)
season_map = {season: val for val, season in enumerate(set(train_df['season']))}
print(season_map)
usage_map = {use: val for val, use in enumerate(set(train_df['usage']))}
print(usage_map)
# Out:
# {'Lips': 0, 'Topwear': 1, 'Watches': 2, 'Free Gifts': 3, 'Accessories': 4, 'Makeup': 5, 'Nails': 6, 'Sandal': 7, 'Headwear': 8, 'Bags': 9, 'Innerwear': 10, 'Flip Flops': 11, 'Saree': 12, 'Ties': 13, 'Cufflinks': 14, 'Jewellery': 15, 'Scarves': 16, 'Belts': 17, 'Socks': 18, 'Dress': 19, 'Apparel Set': 20, 'Bottomwear': 21, 'Shoes': 22, 'Loungewear and Nightwear': 23, 'Fragrance': 24, 'Eyewear': 25, 'Wallets': 26}
# {'Women': 0, 'Girls': 1, 'Unisex': 2, 'Boys': 3, 'Men': 4}
# {'Steel': 0, 'Red': 1, 'Bronze': 2, 'Turquoise Blue': 3, 'Cream': 4, 'Gold': 5, 'Yellow': 6, 'Silver': 7, 'Sea Green': 8, 'Lavender': 9, 'Blue': 10, 'Olive': 11, 'Off White': 12, 'Lime Green': 13, 'Tan': 14, 'Orange': 15, 'Burgundy': 16, 'Khaki': 17, 'Rust': 18, 'Copper': 19, 'Mushroom Brown': 20, 'Beige': 21, 'Black': 22, 'Navy Blue': 23, 'Fluorescent Green': 24, 'Charcoal': 25, 'Grey Melange': 26, 'Metallic': 27, 'Nude': 28, 'Skin': 29, 'Coffee Brown': 30, 'Teal': 31, 'Peach': 32, 'Purple': 33, 'Multi': 34, 'Magenta': 35, 'Mustard': 36, 'Taupe': 37, 'White': 38, 'Brown': 39, 'Grey': 40, 'Maroon': 41, 'Rose': 42, 'Pink': 43, 'Green': 44, 'Mauve': 45}
# {'Spring': 0, 'Summer': 1, 'Winter': 2, 'Fall': 3}
# {'Party': 0, 'Casual': 1, 'Ethnic': 2, 'Smart Casual': 3, 'Formal': 4, 'Sports': 5, 'Travel': 6}

# %%
max_words = 17

# %% [markdown]
# # Build Vocabulary

# %%
tokenizer = get_tokenizer(tokenizer='spacy')
train_iter = iter(train_df['noisyTextDescription'])

def yield_tokens(data_iter):
    for text in data_iter:
        yield tokenizer(text)

vocab = build_vocab_from_iterator(yield_tokens(train_iter), specials=["<unk>"])
vocab.set_default_index(vocab["<unk>"])

vocab_size = len(vocab)
print(vocab_size)
# Out:
# 9054

# %% [markdown]
# # Image transformation

# %%
transform = transforms.Compose([
    transforms.ToTensor(),
    transforms.Normalize(mean=[0.485, 0.456, 0.406],std=[0.229, 0.224, 0.225])
])

# %% [markdown]
# # Input encoding

# %%
text_pipeline = lambda x: vocab(tokenizer(x))
gender_pipeline = lambda x: gender_map.get(x)
color_pipeline = lambda x: color_map.get(x)
season_pipeline = lambda x: season_map.get(x)
use_pipeline = lambda x: usage_map.get(x)
cat_pipeline = lambda x: category_map.get(x)

# %% [markdown]
# # Format input and output
#
# credit: https://pytorch.org/tutorials/beginner/basics/data_tutorial.html

# %%
class TextImageDataset(Dataset):
    def __init__(self, data_list, transform=None):
        self.data_list = data_list
        self.transform = transform
        self.translate()
        
    def translate(self):
        self.data_list.noisyTextDescription = [text_pipeline(text) for text in self.data_list.noisyTextDescription]
        self.data_list.noisyTextDescription = [text + [0]*(max_words-len(text)) for text in self.data_list.noisyTextDescription]
        self.data_list.gender = [gender_pipeline(gender) for gender in self.data_list.gender]
        self.data_list.baseColour = [color_pipeline(color) for color in self.data_list.baseColour]
        self.data_list.season = [season_pipeline(season) for season in self.data_list.season]
        self.data_list.usage = [use_pipeline(use) for use in self.data_list.usage]
        self.data_list.category = [cat_pipeline(cat) for cat in self.data_list.category]

    def __len__(self):
        return len(self.data_list.category)

    def __getitem__(self, idx):
        if torch.is_tensor(idx):
            idx = idx.tolist()
        
        id = self.data_list['id'].iloc[idx]
        image_path = f'/content/noisy-images/{id}.jpg'
        image = Image.open(image_path)
        if self.transform is not None:
            image = self.transform(image)

        text = torch.tensor(self.data_list['noisyTextDescription'].iloc[idx])
        gender = self.data_list['gender'].iloc[idx]
        color = self.data_list['baseColour'].iloc[idx]
        season = self.data_list['season'].iloc[idx]
        usage = self.data_list['usage'].iloc[idx]
        category = self.data_list['category'].iloc[idx]
        
        return text, gender, color, season, usage, image, category

# %% [markdown]
# # Model

# %% [markdown]
# ###Input:
# a combination of noisy text, noisy image, and other categorical variables (gender, color, season, and usage)
#
# ###Output:
# a prediction for 27 classes.
#
# The model architecture consists of several layers:
#
# ###Text layer:
# Embeds the input text using an embedding layer, applies convolutional filters of size [3, 4, 5], and concatenates the outputs. \
# (I used CNN instead of RNN because CNN achieved a higher accuracy)
#
# ###Categorical layers:
# Embed the corresponding categorical input variables using an embedding layer and flatten the output.
#
# ###Image layer:
# Applies a sequence of convolutional and pooling layers to the input image and flattens the output.
#
# ###Output layer:
# Concatenates all the previous outputs, applies dropout regularization (prevent overfitting), and applies a fully connected layer followed by a softmax activation function to output the predicted class probabilities.

# %%
class Model(nn.Module):
    def __init__(self, vocab_size=vocab_size, embedding_dim=100, num_class=27, num_filters=100, filter_sizes=[3,4,5], dropout_prob=0.25):
        super(Model, self).__init__()

        # Text layer
        self.text_embedding = nn.Embedding(vocab_size, embedding_dim)
        self.convs = nn.ModuleList([nn.Conv2d(1, num_filters, (fs, embedding_dim)) for fs in filter_sizes])

        # Gender layer
        self.gender_embedding = nn.Embedding(5, num_filters)

        # Color layer
        self.color_embedding = nn.Embedding(46, num_filters)

        # Season layer
        self.season_embedding = nn.Embedding(4, num_filters)

        # Usage layer
        self.usage_embedding = nn.Embedding(7, num_filters)

        # Image layer
        self.image_cnn = nn.Sequential(
            nn.Conv2d(in_channels=3, out_channels=8, kernel_size=3, stride=1, padding=1),
            nn.ReLU(),
            nn.MaxPool2d(kernel_size=2, stride=2),
            nn.Conv2d(in_channels=8, out_channels=16, kernel_size=3, stride=1, padding=1),
            nn.ReLU(),
            nn.MaxPool2d(kernel_size=2, stride=2),
            nn.Conv2d(in_channels=16, out_channels=32, kernel_size=3, stride=1, padding=1),
            nn.ReLU(),
            nn.MaxPool2d(kernel_size=2, stride=2),
            nn.Flatten(),
            nn.Linear(in_features=2240, out_features=256),
            nn.ReLU(),
        )
        
        # Output layer
        self.dropout = nn.Dropout(dropout_prob)
        self.fc = nn.Linear(len(filter_sizes) * num_filters + 256 + num_filters * 4, num_class)
        self.softmax = nn.LogSoftmax(dim=1)

    def forward(self, text, gender, color, season, usage, image):
        # Text input forward
        text_embedded = self.text_embedding(text)
        text_embedded = text_embedded.unsqueeze(1)
        text_conv_outputs = []
        for conv in self.convs:
            conv_output = nn.functional.relu(conv(text_embedded))
            conv_output = nn.functional.max_pool2d(conv_output, (conv_output.shape[2], 1))
            text_conv_outputs.append(conv_output.squeeze())
        text_output = torch.cat(text_conv_outputs, dim=1)

        # Gender input forward
        gender_embedded = self.gender_embedding(gender)
        gender_output = gender_embedded.squeeze(1)

        # Color input forward
        color_embedded = self.color_embedding(color)
        color_output = color_embedded.squeeze(1)

        # Season input forward
        season_embedded = self.season_embedding(season)
        season_output = season_embedded.squeeze(1)

        # Usage input forward
        usage_embedded = self.usage_embedding(usage)
        usage_output = usage_embedded.squeeze(1)

        # Image input forward
        image_output = self.image_cnn(image)

        # Output
        output = torch.cat([text_output, image_output, gender_output, color_output, season_output, usage_output], dim=1)
        output = self.dropout(output)
        output = self.softmax(self.fc(output))
        return output

# %% [markdown]
# # Train, Evaluate and Test

# %%
def train(model, dataloader, optimizer, criterion):
    model.train()
    total_acc, total_count = 0, 0
    log_interval = 200
    start_time = time.time()

    for idx, (text, gender, color, season, usage, image, label) in enumerate(dataloader):
        text, gender, color, season, usage, image, label = text.to(device), gender.to(device), color.to(device), season.to(device), usage.to(device), image.to(device), label.to(device)
        optimizer.zero_grad()
        predicted_label = model(text, gender, color, season, usage, image)
        loss = criterion(predicted_label, label)
        loss.backward()
        torch.nn.utils.clip_grad_norm_(model.parameters(), 0.1)
        optimizer.step()
        total_acc += (predicted_label.argmax(1) == label).sum().item()
        total_count += label.size(0)
        if idx % log_interval == 0 and idx > 0:
            elapsed = time.time() - start_time
            print('| {:5d}/{:5d} batches '
                  '| accuracy {:8.3f}'.format(idx, len(dataloader),
                                              total_acc/total_count))
            total_acc, total_count = 0, 0
            start_time = time.time()

def evaluate(model, dataloader, criterion):
    model.eval()
    total_acc, total_count = 0, 0

    with torch.no_grad():
        for idx, (text, gender, color, season, usage, image, label) in enumerate(dataloader):
            text, gender, color, season, usage, image, label = text.to(device), gender.to(device), color.to(device), season.to(device), usage.to(device), image.to(device), label.to(device)
            predicted_label = model(text, gender, color, season, usage, image)
            loss = criterion(predicted_label, label)
            total_acc += (predicted_label.argmax(1) == label).sum().item()
            total_count += label.size(0)
    return total_acc/total_count

def test(model, dataloader):
    model.eval()
    predictions = []
    with torch.no_grad():
        for idx, (text, gender, color, season, usage, image, label) in enumerate(dataloader):
            text, gender, color, season, usage, image, label = text.to(device), gender.to(device), color.to(device), season.to(device), usage.to(device), image.to(device), label.to(device)
            predicted_label = model(text, gender, color, season, usage, image)
            predictions += predicted_label.argmax(1).tolist()
    return predictions

# %% [markdown]
# # Start

# %%
EPOCHS = 10 # epoch
BATCH_SIZE = 64 # batch size for training

def fit(train_df, valid_df):
  # Define the model, loss function, and optimizer
  model = Model().to(device)
  criterion = nn.CrossEntropyLoss()
  optimizer = optim.Adam(model.parameters(), lr=0.001)
  scheduler = torch.optim.lr_scheduler.StepLR(optimizer, 1.0, gamma=0.1)
  total_accu = None
  train_dataset = TextImageDataset(train_df, transform=transform)
  valid_dataset = TextImageDataset(valid_df, transform=transform)
  train_loader = DataLoader(train_dataset, batch_size=BATCH_SIZE, shuffle=True, num_workers=4, pin_memory=True)
  valid_loader = DataLoader(valid_dataset, batch_size=BATCH_SIZE, num_workers=4, pin_memory=True)
  for epoch in range(1, EPOCHS + 1):
    epoch_start_time = time.time()
    train(model, train_loader, optimizer, criterion)
    accu_val = evaluate(model, valid_loader, criterion)
    if total_accu is not None and total_accu > accu_val:
      scheduler.step()
    else:
       total_accu = accu_val
    print('-' * 59)
    print('| end of epoch {:3d} | time: {:5.2f}s | ''valid accuracy {:8.3f} '.format(epoch, time.time() - epoch_start_time, accu_val))
    print('-' * 59)
  return model

# %% [markdown]
# # Bagging

# %% [markdown]
# ###The Ensemble learning technique I used is Bagging.
# ###Train 10 weak models and make the final prediction using majority voting.

# %%
n_estimators = 10

# Store all models
all_models = []

for i in range(n_estimators):
    # Randomly split the training data to train and validation dataset
    train_df_subset, valid_df_subset = train_test_split(train_df, test_size=0.2, random_state=i)

    print(f"Model {i}:")
    model = fit(train_df_subset, valid_df_subset)
    all_models.append(model)
# Out:
# Model 0:
# |   200/  271 batches | accuracy    0.741
# -----------------------------------------------------------
# | end of epoch   1 | time: 21.98s | valid accuracy    0.866
# -----------------------------------------------------------
# |   200/  271 batches | accuracy    0.886
# -----------------------------------------------------------
# | end of epoch   2 | time: 23.00s | valid accuracy    0.884
# -----------------------------------------------------------
# |   200/  271 batches | accuracy    0.915
# -----------------------------------------------------------
# | end of epoch   3 | time: 22.00s | valid accuracy    0.888
# -----------------------------------------------------------
# |   200/  271 batches | accuracy    0.943
# -----------------------------------------------------------
# | end of epoch   4 | time: 22.50s | valid accuracy    0.886
# -----------------------------------------------------------
# |   200/  271 batches | accuracy    0.973
# -----------------------------------------------------------
# | end of epoch   5 | time: 22.09s | valid accuracy    0.894
# -----------------------------------------------------------
# |   200/  271 batches | accuracy    0.976
# -----------------------------------------------------------
# | end of epoch   6 | time: 22.62s | valid accuracy    0.895
# -----------------------------------------------------------
# |   200/  271 batches | accuracy    0.983
# -----------------------------------------------------------
# | end of epoch   7 | time: 22.09s | valid accuracy    0.896
# -----------------------------------------------------------
# |   200/  271 batches | accuracy    0.985
# -----------------------------------------------------------
# | end of epoch   8 | time: 22.79s | valid accuracy    0.896
# -----------------------------------------------------------
# |   200/  271 batches | accuracy    0.988
# -----------------------------------------------------------
# | end of epoch   9 | time: 22.45s | valid accuracy    0.896
# -----------------------------------------------------------
# |   200/  271 batches | accuracy    0.986
# -----------------------------------------------------------
# | end of epoch  10 | time: 22.25s | valid accuracy    0.897
# -----------------------------------------------------------
# Model 1:
# |   200/  271 batches | accuracy    0.735
# -----------------------------------------------------------
# | end of epoch   1 | time: 23.00s | valid accuracy    0.869
# -----------------------------------------------------------
# |   200/  271 batches | accuracy    0.887
# -----------------------------------------------------------
# | end of epoch   2 | time: 22.04s | valid accuracy    0.881
# -----------------------------------------------------------
# |   200/  271 batches | accuracy    0.922
# -----------------------------------------------------------
# | end of epoch   3 | time: 23.45s | valid accuracy    0.884
# -----------------------------------------------------------
# |   200/  271 batches | accuracy    0.944
# -----------------------------------------------------------
# | end of epoch   4 | time: 21.59s | valid accuracy    0.889
# -----------------------------------------------------------
# |   200/  271 batches | accuracy    0.961
# -----------------------------------------------------------
# | end of epoch   5 | time: 23.53s | valid accuracy    0.883
# -----------------------------------------------------------
# |   200/  271 batches | accuracy    0.982
# -----------------------------------------------------------
# | end of epoch   6 | time: 21.70s | valid accuracy    0.895
# -----------------------------------------------------------
# |   200/  271 batches | accuracy    0.987
# -----------------------------------------------------------
# | end of epoch   7 | time: 23.16s | valid accuracy    0.896
# -----------------------------------------------------------
# |   200/  271 batches | accuracy    0.990
# -----------------------------------------------------------
# | end of epoch   8 | time: 21.74s | valid accuracy    0.895
# -----------------------------------------------------------
# |   200/  271 batches | accuracy    0.992
# -----------------------------------------------------------
# | end of epoch   9 | time: 22.76s | valid accuracy    0.895
# -----------------------------------------------------------
# |   200/  271 batches | accuracy    0.992
# -----------------------------------------------------------
# | end of epoch  10 | time: 21.66s | valid accuracy    0.894
# -----------------------------------------------------------
# Model 2:
# |   200/  271 batches | accuracy    0.742
# -----------------------------------------------------------
# | end of epoch   1 | time: 22.79s | valid accuracy    0.862
# -----------------------------------------------------------
# |   200/  271 batches | accuracy    0.885
# -----------------------------------------------------------
# | end of epoch   2 | time: 21.88s | valid accuracy    0.887
# -----------------------------------------------------------
# |   200/  271 batches | accuracy    0.915
# -----------------------------------------------------------
# | end of epoch   3 | time: 23.15s | valid accuracy    0.879
# -----------------------------------------------------------
# |   200/  271 batches | accuracy    0.955
# -----------------------------------------------------------
# | end of epoch   4 | time: 21.68s | valid accuracy    0.899
# -----------------------------------------------------------
# |   200/  271 batches | accuracy    0.961
# -----------------------------------------------------------
# | end of epoch   5 | time: 22.74s | valid accuracy    0.900
# -----------------------------------------------------------
# |   200/  271 batches | accuracy    0.966
# -----------------------------------------------------------
# | end of epoch   6 | time: 21.73s | valid accuracy    0.900
# -----------------------------------------------------------
# |   200/  271 batches | accuracy    0.971
# -----------------------------------------------------------
# | end of epoch   7 | time: 22.90s | valid accuracy    0.900
# -----------------------------------------------------------
# |   200/  271 batches | accuracy    0.972
# -----------------------------------------------------------
# | end of epoch   8 | time: 21.69s | valid accuracy    0.900
# -----------------------------------------------------------
# |   200/  271 batches | accuracy    0.973
# -----------------------------------------------------------
# | end of epoch   9 | time: 22.62s | valid accuracy    0.900
# -----------------------------------------------------------
# |   200/  271 batches | accuracy    0.972
# -----------------------------------------------------------
# | end of epoch  10 | time: 21.56s | valid accuracy    0.900
# -----------------------------------------------------------
# Model 3:
# |   200/  271 batches | accuracy    0.742
# -----------------------------------------------------------
# | end of epoch   1 | time: 22.46s | valid accuracy    0.862
# -----------------------------------------------------------
# |   200/  271 batches | accuracy    0.880
# -----------------------------------------------------------
# | end of epoch   2 | time: 22.80s | valid accuracy    0.886
# -----------------------------------------------------------
# |   200/  271 batches | accuracy    0.920
# -----------------------------------------------------------
# | end of epoch   3 | time: 21.98s | valid accuracy    0.885
# -----------------------------------------------------------
# |   200/  271 batches | accuracy    0.959
# -----------------------------------------------------------
# | end of epoch   4 | time: 23.17s | valid accuracy    0.896
# -----------------------------------------------------------
# |   200/  271 batches | accuracy    0.963
# -----------------------------------------------------------
# | end of epoch   5 | time: 22.03s | valid accuracy    0.898
# -----------------------------------------------------------
# |   200/  271 batches | accuracy    0.968
# -----------------------------------------------------------
# | end of epoch   6 | time: 23.11s | valid accuracy    0.898
# -----------------------------------------------------------
# |   200/  271 batches | accuracy    0.973
# -----------------------------------------------------------
# | end of epoch   7 | time: 22.05s | valid accuracy    0.899
# -----------------------------------------------------------
# |   200/  271 batches | accuracy    0.974
# -----------------------------------------------------------
# | end of epoch   8 | time: 23.55s | valid accuracy    0.899
# -----------------------------------------------------------
# |   200/  271 batches | accuracy    0.979
# -----------------------------------------------------------
# | end of epoch   9 | time: 21.61s | valid accuracy    0.901
# -----------------------------------------------------------
# |   200/  271 batches | accuracy    0.978
# -----------------------------------------------------------
# | end of epoch  10 | time: 23.22s | valid accuracy    0.902
# -----------------------------------------------------------
# Model 4:
# |   200/  271 batches | accuracy    0.739
# -----------------------------------------------------------
# | end of epoch   1 | time: 21.59s | valid accuracy    0.872
# -----------------------------------------------------------
# |   200/  271 batches | accuracy    0.878
# -----------------------------------------------------------
# | end of epoch   2 | time: 22.61s | valid accuracy    0.890
# -----------------------------------------------------------
# |   200/  271 batches | accuracy    0.917
# -----------------------------------------------------------
# | end of epoch   3 | time: 21.07s | valid accuracy    0.888
# -----------------------------------------------------------
# |   200/  271 batches | accuracy    0.957
# -----------------------------------------------------------
# | end of epoch   4 | time: 22.59s | valid accuracy    0.899
# -----------------------------------------------------------
# |   200/  271 batches | accuracy    0.964
# -----------------------------------------------------------
# | end of epoch   5 | time: 21.28s | valid accuracy    0.898
# -----------------------------------------------------------
# |   200/  271 batches | accuracy    0.972
# -----------------------------------------------------------
# | end of epoch   6 | time: 22.58s | valid accuracy    0.897
# -----------------------------------------------------------
# |   200/  271 batches | accuracy    0.971
# -----------------------------------------------------------
# | end of epoch   7 | time: 21.11s | valid accuracy    0.897
# -----------------------------------------------------------
# |   200/  271 batches | accuracy    0.970
# -----------------------------------------------------------
# | end of epoch   8 | time: 22.37s | valid accuracy    0.897
# -----------------------------------------------------------
# |   200/  271 batches | accuracy    0.972
# -----------------------------------------------------------
# | end of epoch   9 | time: 21.24s | valid accuracy    0.897
# -----------------------------------------------------------
# |   200/  271 batches | accuracy    0.971
# -----------------------------------------------------------
# | end of epoch  10 | time: 22.62s | valid accuracy    0.897
# -----------------------------------------------------------
# Model 5:
# |   200/  271 batches | accuracy    0.735
# -----------------------------------------------------------
# | end of epoch   1 | time: 21.41s | valid accuracy    0.860
# -----------------------------------------------------------
# |   200/  271 batches | accuracy    0.882
# -----------------------------------------------------------
# | end of epoch   2 | time: 22.48s | valid accuracy    0.879
# -----------------------------------------------------------
# |   200/  271 batches | accuracy    0.922
# -----------------------------------------------------------
# | end of epoch   3 | time: 21.38s | valid accuracy    0.886
# -----------------------------------------------------------
# |   200/  271 batches | accuracy    0.943
# -----------------------------------------------------------
# | end of epoch   4 | time: 22.42s | valid accuracy    0.891
# -----------------------------------------------------------
# |   200/  271 batches | accuracy    0.960
# -----------------------------------------------------------
# | end of epoch   5 | time: 21.28s | valid accuracy    0.881
# -----------------------------------------------------------
# |   200/  271 batches | accuracy    0.984
# -----------------------------------------------------------
# | end of epoch   6 | time: 22.62s | valid accuracy    0.896
# -----------------------------------------------------------
# |   200/  271 batches | accuracy    0.988
# -----------------------------------------------------------
# | end of epoch   7 | time: 21.29s | valid accuracy    0.896
# -----------------------------------------------------------
# |   200/  271 batches | accuracy    0.991
# -----------------------------------------------------------
# | end of epoch   8 | time: 22.62s | valid accuracy    0.896
# -----------------------------------------------------------
# |   200/  271 batches | accuracy    0.991
# -----------------------------------------------------------
# | end of epoch   9 | time: 21.40s | valid accuracy    0.896
# -----------------------------------------------------------
# |   200/  271 batches | accuracy    0.991
# -----------------------------------------------------------
# | end of epoch  10 | time: 22.55s | valid accuracy    0.896
# -----------------------------------------------------------
# Model 6:
# |   200/  271 batches | accuracy    0.733
# -----------------------------------------------------------
# | end of epoch   1 | time: 21.36s | valid accuracy    0.866
# -----------------------------------------------------------
# |   200/  271 batches | accuracy    0.877
# -----------------------------------------------------------
# | end of epoch   2 | time: 22.79s | valid accuracy    0.885
# -----------------------------------------------------------
# |   200/  271 batches | accuracy    0.917
# -----------------------------------------------------------
# | end of epoch   3 | time: 21.34s | valid accuracy    0.892
# -----------------------------------------------------------
# |   200/  271 batches | accuracy    0.943
# -----------------------------------------------------------
# | end of epoch   4 | time: 22.68s | valid accuracy    0.881
# -----------------------------------------------------------
# |   200/  271 batches | accuracy    0.971
# -----------------------------------------------------------
# | end of epoch   5 | time: 21.30s | valid accuracy    0.898
# -----------------------------------------------------------
# |   200/  271 batches | accuracy    0.979
# -----------------------------------------------------------
# | end of epoch   6 | time: 23.60s | valid accuracy    0.897
# -----------------------------------------------------------
# |   200/  271 batches | accuracy    0.982
# -----------------------------------------------------------
# | end of epoch   7 | time: 21.39s | valid accuracy    0.898
# -----------------------------------------------------------
# |   200/  271 batches | accuracy    0.983
# -----------------------------------------------------------
# | end of epoch   8 | time: 22.47s | valid accuracy    0.899
# -----------------------------------------------------------
# |   200/  271 batches | accuracy    0.983
# -----------------------------------------------------------
# | end of epoch   9 | time: 21.30s | valid accuracy    0.899
# -----------------------------------------------------------
# |   200/  271 batches | accuracy    0.982
# -----------------------------------------------------------
# | end of epoch  10 | time: 22.66s | valid accuracy    0.899
# -----------------------------------------------------------
# Model 7:
# |   200/  271 batches | accuracy    0.734
# -----------------------------------------------------------
# | end of epoch   1 | time: 21.59s | valid accuracy    0.864
# -----------------------------------------------------------
# |   200/  271 batches | accuracy    0.882
# -----------------------------------------------------------
# | end of epoch   2 | time: 22.67s | valid accuracy    0.879
# -----------------------------------------------------------
# |   200/  271 batches | accuracy    0.916
# -----------------------------------------------------------
# | end of epoch   3 | time: 21.39s | valid accuracy    0.883
# -----------------------------------------------------------
# |   200/  271 batches | accuracy    0.937
# -----------------------------------------------------------
# | end of epoch   4 | time: 22.70s | valid accuracy    0.889
# -----------------------------------------------------------
# |   200/  271 batches | accuracy    0.957
# -----------------------------------------------------------
# | end of epoch   5 | time: 21.38s | valid accuracy    0.890
# -----------------------------------------------------------
# |   200/  271 batches | accuracy    0.972
# -----------------------------------------------------------
# | end of epoch   6 | time: 22.59s | valid accuracy    0.890
# -----------------------------------------------------------
# |   200/  271 batches | accuracy    0.978
# -----------------------------------------------------------
# | end of epoch   7 | time: 21.58s | valid accuracy    0.891
# -----------------------------------------------------------
# |   200/  271 batches | accuracy    0.981
# -----------------------------------------------------------
# | end of epoch   8 | time: 22.39s | valid accuracy    0.889
# -----------------------------------------------------------
# |   200/  271 batches | accuracy    0.991
# -----------------------------------------------------------
# | end of epoch   9 | time: 22.74s | valid accuracy    0.899
# -----------------------------------------------------------
# |   200/  271 batches | accuracy    0.995
# -----------------------------------------------------------
# | end of epoch  10 | time: 22.19s | valid accuracy    0.898
# -----------------------------------------------------------
# Model 8:
# |   200/  271 batches | accuracy    0.745
# -----------------------------------------------------------
# | end of epoch   1 | time: 21.53s | valid accuracy    0.851
# -----------------------------------------------------------
# |   200/  271 batches | accuracy    0.880
# -----------------------------------------------------------
# | end of epoch   2 | time: 22.33s | valid accuracy    0.874
# -----------------------------------------------------------
# |   200/  271 batches | accuracy    0.918
# -----------------------------------------------------------
# | end of epoch   3 | time: 21.28s | valid accuracy    0.886
# -----------------------------------------------------------
# |   200/  271 batches | accuracy    0.941
# -----------------------------------------------------------
# | end of epoch   4 | time: 22.42s | valid accuracy    0.880
# -----------------------------------------------------------
# |   200/  271 batches | accuracy    0.971
# -----------------------------------------------------------
# | end of epoch   5 | time: 23.00s | valid accuracy    0.892
# -----------------------------------------------------------
# |   200/  271 batches | accuracy    0.977
# -----------------------------------------------------------
# | end of epoch   6 | time: 21.87s | valid accuracy    0.892
# -----------------------------------------------------------
# |   200/  271 batches | accuracy    0.984
# -----------------------------------------------------------
# | end of epoch   7 | time: 22.09s | valid accuracy    0.893
# -----------------------------------------------------------
# |   200/  271 batches | accuracy    0.981
# -----------------------------------------------------------
# | end of epoch   8 | time: 23.77s | valid accuracy    0.893
# -----------------------------------------------------------
# |   200/  271 batches | accuracy    0.983
# -----------------------------------------------------------
# | end of epoch   9 | time: 23.97s | valid accuracy    0.892
# -----------------------------------------------------------
# |   200/  271 batches | accuracy    0.983
# -----------------------------------------------------------
# | end of epoch  10 | time: 21.42s | valid accuracy    0.892
# -----------------------------------------------------------
# Model 9:
# |   200/  271 batches | accuracy    0.744
# -----------------------------------------------------------
# | end of epoch   1 | time: 22.46s | valid accuracy    0.856
# -----------------------------------------------------------
# |   200/  271 batches | accuracy    0.884
# -----------------------------------------------------------
# | end of epoch   2 | time: 21.63s | valid accuracy    0.876
# -----------------------------------------------------------
# |   200/  271 batches | accuracy    0.921
# -----------------------------------------------------------
# | end of epoch   3 | time: 23.71s | valid accuracy    0.884
# -----------------------------------------------------------
# |   200/  271 batches | accuracy    0.944
# -----------------------------------------------------------
# | end of epoch   4 | time: 21.70s | valid accuracy    0.882
# -----------------------------------------------------------
# |   200/  271 batches | accuracy    0.975
# -----------------------------------------------------------
# | end of epoch   5 | time: 23.50s | valid accuracy    0.891
# -----------------------------------------------------------
# |   200/  271 batches | accuracy    0.981
# -----------------------------------------------------------
# | end of epoch   6 | time: 23.01s | valid accuracy    0.890
# -----------------------------------------------------------
# |   200/  271 batches | accuracy    0.984
# -----------------------------------------------------------
# | end of epoch   7 | time: 22.70s | valid accuracy    0.891
# -----------------------------------------------------------
# |   200/  271 batches | accuracy    0.985
# -----------------------------------------------------------
# | end of epoch   8 | time: 23.53s | valid accuracy    0.892
# -----------------------------------------------------------
# |   200/  271 batches | accuracy    0.986
# -----------------------------------------------------------
# | end of epoch   9 | time: 21.74s | valid accuracy    0.892
# -----------------------------------------------------------
# |   200/  271 batches | accuracy    0.985
# -----------------------------------------------------------
# | end of epoch  10 | time: 23.43s | valid accuracy    0.892
# -----------------------------------------------------------

# %% [markdown]
# # Decoding category

# %%
def get_key(val):
    for key, value in category_map.items():
        if value == val:
            return key

# %% [markdown]
# # Validation accuracy
#
# If you want to try validation accuracy, uncomment the code at the data import section.

# %%
valid_dataset = TextImageDataset(valid_df, transform=transform)
valid_loader = DataLoader(valid_dataset, batch_size=BATCH_SIZE, shuffle=False)

valid_preds = []
for mod in all_models:
    valid_pred = test(mod, valid_loader)
    valid_preds.append(valid_pred)
    
# Combine the predictions using majority voting
valid_preds = np.array(valid_preds)
valid_pred = np.apply_along_axis(lambda x: np.argmax(np.bincount(x)), axis=0, arr=valid_preds)
accuracy = (valid_pred == valid_df.category).sum() / len(valid_df)
print(accuracy)
# Out:
# 0.903837263060564

# %% [markdown]
# # Validation accuracy
# 0.903837263060564

# %% [markdown]
# # Predict test data

# %%
test_df['category'] = 'Accessories' # Dummy
test_dataset = TextImageDataset(test_df, transform=transform)
test_loader = DataLoader(test_dataset, batch_size=BATCH_SIZE, shuffle=False)

test_preds = []
for mod in all_models:
    test_pred = test(mod, test_loader)
    test_preds.append(test_pred)
    
# Combine the predictions using majority voting
test_preds = np.array(test_preds)
test_pred = np.apply_along_axis(lambda x: np.argmax(np.bincount(x)), axis=0, arr=test_preds)

# %%
predict = pd.DataFrame({'id': test_df.id})
predict['category'] = test_pred
predict['category'] = [get_key(value) for value in predict['category']]
predict
# Out:
#           id    category
# 0      55581  Bottomwear
# 1       8832      Sandal
# 2      29112        Bags
# 3      30961       Shoes
# 4      49668     Wallets
# ...      ...         ...
# 21623  17255     Topwear
# 21624  39606       Shoes
# 21625  41829     Wallets
# 21626  27416     Topwear
# 21627  24079     Topwear
#
# [21628 rows x 2 columns]

# %% [markdown]
# # Download prediction

# %%
predict.to_csv('predict.csv', index=False)
